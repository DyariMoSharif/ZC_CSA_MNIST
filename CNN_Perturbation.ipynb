# %% [markdown]
# ## Perturbation on 500 Samples from train/seen set using CNN

# %% [markdown]
# #### ZC-CSA

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = True           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "CNN.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e10,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "CNN_500_samples_test.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/cnn_ZC-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "cnn_zc_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "cnn_zc_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\CNN.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -2062230.32240
#     iter 20/100 — best fitness -34846171.54797
#     iter 30/100 — best fitness -192862585.36638
#     iter 40/100 — best fitness -3238030145.14410
#     iter 50/100 — best fitness -6189036437.54565
#     iter 60/100 — best fitness -9487049040.62299
#     iter 70/100 — best fitness -24876219085.56482
#     iter 80/100 — best fitness -67449549526.10767
#     iter 90/100 — best fitness -100088232836.30396
#     iter 100/100 — best fitness -103169621311.79858
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -322004.17794
#     iter 30/100 — best fitness -1275594.28991
#     iter 40/100 — best fitness -5669301.23068
#     iter 50/100 — best fitness -665999610.05223
#     iter 60/100 — best fitness -1077823446.08627
#     iter 70/100 — best fitness -6996231775.35455
#     iter 80/100 — best fitness -17888244484.60864
#     iter 90/100 — best fitness -34303590149.58569
#     iter 100/100 — best fitness -53948329768.22229
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample
#     iter 100/100 — best fitness -205993460475.75659
#   sample 43/50 (global 42)
#     iter 1/100 — best fitness -27161.00926
#     iter 10/100 — best fitness -64697569742.38953
#     iter 20/100 — best fitness -108560265394.87781
#     iter 30/100 — best fitness -138082808336.47375
#     iter 40/100 — best fitness -205165213413.99878
#     iter 50/100 — best fitness -221824587634.39917
#     iter 60/100 — best fitness -229891337204.55286
#     iter 70/100 — best fitness -264058550639.18237
#     iter 80/100 — best fitness -272107313912.69482
#     iter 90/100 — best fitness -284864348208.01733
#     iter 100/100 — best fitness -304516257072.94897
#   sample 44/50 (global 43)
#     iter 1/100 — best fitness -2101.22359
#     iter 10/100 — best fitness -5033512266.17883
#     iter 20/100 — best fitness -51348060461.81067
#     iter 30/100 — best fitness -85170677944.72693
#     iter 40/100 — best fitness -118653782733.77014
#     iter 50/100 — best fitness -136160038823.34387
#     iter 60/100 — best fitness -155839003430.30981
#     iter 70/100 — best fitness -174630221226.89355
#     iter 80/100 — best fitness -196430929988.46423
#     iter 90/100 — best fitness -230149115410.48608
#     iter 100/100 — best fitness -241614874684.57446
#   sample 45/50 (global 44)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 46/50 (global 45)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 47/50 (global 46)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 48/50 (global 47)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 49/50 (global 48)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 50/50 (global 49)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 2/50 (global 51)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 3/50 (global 52)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 4/50 (global 53)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 5/50 (global 54)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -157.91851
#     iter 30/100 — best fitness -9675.78191
#     iter 40/100 — best fitness -16813.37459
#     iter 50/100 — best fitness -263555.60727
#     iter 60/100 — best fitness -5859892.87530
#     iter 70/100 — best fitness -22040220.68240
#     iter 80/100 — best fitness -31528854.84811
#     iter 90/100 — best fitness -83953852.07217
#     iter 100/100 — best fitness -83953852.07217
#   sample 6/50 (global 55)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -57353.22124
#     iter 20/100 — best fitness -1699882.90816
#     iter 30/100 — best fitness -37055496.60152
#     iter 40/100 — best fitness -1337221929.38953
#     iter 50/100 — best fitness -1337221929.38953
#     iter 60/100 — best fitness -11643227407.81824
#     iter 70/100 — best fitness -12937544644.28577
#     iter 80/100 — best fitness -17388476188.75598
#     iter 90/100 — best fitness -30923878012.38867
#     iter 100/100 — best fitness -74625333600.62207
#   sample 7/50 (global 56)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 8/50 (global 57)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 9/50 (global 58)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 10/50 (global 59)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 11/50 (global 60)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 12/50 (global 61)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 13/50 (global 62)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 14/50 (global 63)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 15/50 (global 64)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 16/50 (global 65)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -29964.02378
#     iter 30/100 — best fitness -733256.20737
#     iter 40/100 — best fitness -11963942.26829
#     iter 50/100 — best fitness -32271567.12019
#     iter 60/100 — best fitness -3269539854.93893
#     iter 70/100 — best fitness -15731045089.71155
#     iter 80/100 — best fitness -23847972235.35767
#     iter 90/100 — best fitness -31226300087.43408
#     iter 100/100 — best fitness -38297771291.68127
#   sample 17/50 (global 66)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 18/50 (global 67)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 19/50 (global 68)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 20/50 (global 69)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 21/50 (global 70)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 22/50 (global 71)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 23/50 (global 72)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 24/50 (global 73)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 25/50 (global 74)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -2586.36082
#   sample 26/50 (global 75)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample

#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -1308977.35329
#     iter 20/100 — best fitness -272712834.17748
#     iter 30/100 — best fitness -6891279948.47223
#     iter 40/100 — best fitness -30474263489.28589
#     iter 50/100 — best fitness -66456092685.32800
#     iter 60/100 — best fitness -101627901835.24548
#     iter 70/100 — best fitness -102582720563.90857
#     iter 80/100 — best fitness -117309836197.14526
#     iter 90/100 — best fitness -130441435622.04993
#     iter 100/100 — best fitness -133934496691.72168
#   sample 34/50 (global 483)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -9242364937.80011
#     iter 20/100 — best fitness -68425792612.08643
#     iter 30/100 — best fitness -96781796310.28186
#     iter 40/100 — best fitness -145764817079.18591
#     iter 50/100 — best fitness -154674223733.01477
#     iter 60/100 — best fitness -181916521844.39258
#     iter 70/100 — best fitness -201641787345.13696
#     iter 80/100 — best fitness -211185168057.45813
#     iter 90/100 — best fitness -219544562133.19861
#     iter 100/100 — best fitness -226749590663.69519
#   sample 35/50 (global 484)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 36/50 (global 485)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 37/50 (global 486)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 38/50 (global 487)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -5317844.97799
#     iter 20/100 — best fitness -402492498.47978
#     iter 30/100 — best fitness -56304215295.37988
#     iter 40/100 — best fitness -127685765103.96716
#     iter 50/100 — best fitness -137923754524.46265
#     iter 60/100 — best fitness -147946928809.87988
#     iter 70/100 — best fitness -160278300118.56323
#     iter 80/100 — best fitness -179009207558.37109
#     iter 90/100 — best fitness -200559157216.49548
#     iter 100/100 — best fitness -223573645433.84155
#   sample 39/50 (global 488)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 40/50 (global 489)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -3730.98031
#     iter 20/100 — best fitness -31141.24714
#     iter 30/100 — best fitness -844106.87136
#     iter 40/100 — best fitness -12899776.49458
#     iter 50/100 — best fitness -83794292.87040
#     iter 60/100 — best fitness -193698625.39761
#     iter 70/100 — best fitness -483519043.00920
#     iter 80/100 — best fitness -1252630429.16644
#     iter 90/100 — best fitness -2110062906.26953
#     iter 100/100 — best fitness -3433199890.77097
#   sample 41/50 (global 490)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -463859.20118
#     iter 20/100 — best fitness -2167123.25439
#     iter 30/100 — best fitness -186869184.52721
#     iter 40/100 — best fitness -3528103336.79987
#     iter 50/100 — best fitness -58538540687.08716
#     iter 60/100 — best fitness -59041494214.05371
#     iter 70/100 — best fitness -73967708422.18359
#     iter 80/100 — best fitness -76922167613.24146
#     iter 90/100 — best fitness -88580330688.91943
#     iter 100/100 — best fitness -110267676184.55518
#   sample 42/50 (global 491)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 43/50 (global 492)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 44/50 (global 493)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 45/50 (global 494)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 46/50 (global 495)
#     iter 1/100 — best fitness -10461.55004
#     iter 10/100 — best fitness -73103221783.00610
#     iter 20/100 — best fitness -130364359719.45605
#     iter 30/100 — best fitness -156858805486.99573
#     iter 40/100 — best fitness -202167433550.51086
#     iter 50/100 — best fitness -219369582002.50354
#     iter 60/100 — best fitness -241295450996.31543
#     iter 70/100 — best fitness -254183653660.55493
#     iter 80/100 — best fitness -262818068331.25085
#     iter 90/100 — best fitness -304096010945.80994
#     iter 100/100 — best fitness -317508200422.45007
#   sample 47/50 (global 496)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 48/50 (global 497)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -80047.35398
#     iter 40/100 — best fitness -8446136.27915
#     iter 50/100 — best fitness -114757566.24004
#     iter 60/100 — best fitness -2310426354.35974
#     iter 70/100 — best fitness -26652001256.63049
#     iter 80/100 — best fitness -64032739516.04431
#     iter 90/100 — best fitness -80564993739.76440
#     iter 100/100 — best fitness -88491543649.61450
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 123
# Detailed results  CSV    : Generated Data/cnn_ZC-CSA_images\cnn_zc_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/cnn_ZC-CSA_images\cnn_zc_csa_stats_per_digit.csv
# Total time               : 7741.21 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   35             15     50       70.0      30.0
# 1                   47              3     50       94.0       6.0
# 2                   35             15     50       70.0      30.0
# 3                   42              8     50       84.0      16.0
# 4                   33             17     50       66.0      34.0
# 5                   41              9     50       82.0      18.0
# 6                   42              8     50       84.0      16.0
# 7                   37             13     50       74.0      26.0
# 8                   31             19     50       62.0      38.0
# 9                   34             16     50       68.0      32.0

# %% [markdown]
# ### Low query (Low iteration & Low Nests)

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 100.0
raw_lower_bound  = -100.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = True           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "CNN.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e10,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "CNN_500_samples_test.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/LQ-cnn_ZC-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 6
    n_iterations  = 15
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "LQ_cnn_zc_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "LQ_cnn_zc_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\CNN.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -324535179.13446
#     iter 15/15 — best fitness -3169192182.93439
#   sample 2/50 (global 1)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 3/50 (global 2)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -7418118862.27045
#     iter 15/15 — best fitness -23857167499.76257
#   sample 4/50 (global 3)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 5/50 (global 4)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 6/50 (global 5)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -22193.15484
#   sample 7/50 (global 6)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -109043281753.39038
#     iter 15/15 — best fitness -119763258177.91016
#   sample 8/50 (global 7)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -17290937399.11035
#     iter 15/15 — best fitness -25305085846.19812
#   sample 9/50 (global 8)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 10/50 (global 9)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -2664712.81994
#   sample 11/50 (global 10)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 12/50 (global 11)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -94888.40383
#     iter 15/15 — best fitness -2074722.51640
#   sample 13/50 (global 12)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 14/50 (global 13)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -528950204.24995
#     iter 15/15 — best fitness -3040712503.80432
#   sample 15/50 (global 14)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -748.35567
#     iter 15/15 — best fitness -61359805.14438
#   sample 16/50 (global 15)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -861354.72036
#     iter 15/15 — best fitness -4806025.83960
#   sample 17/50 (global 16)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -11927647.43037
#     iter 15/15 — best fitness -139228969.30518
#   sample 18/50 (global 17)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 19/50 (global 18)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -125651701235.81421
#     iter 15/15 — best fitness -166090601191.93640
#   sample 20/50 (global 19)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -38854.36627
#   sample 21/50 (global 20)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -49963792081.14331
#     iter 15/15 — best fitness -102819383807.10303
#   sample 22/50 (global 21)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -18714508489.34766
#     iter 15/15 — best fitness -27289708351.44629
#   sample 23/50 (global 22)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -42692249570.64697
#     iter 15/15 — best fitness -75989988577.83447
#   sample 24/50 (global 23)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -20051201173.09741
#     iter 15/15 — best fitness -30411740088.70996
#   sample 25/50 (global 24)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -112466830.14084
#     iter 15/15 — best fitness -905317790.71040
#   sample 26/50 (global 25)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -26991.30331
#     iter 15/15 — best fitness -36792479.69677
#   sample 27/50 (global 26)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -2996015.70815
#     iter 15/15 — best fitness -14977669.30620
#   sample 28/50 (global 27)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -45434083.68787
#     iter 15/15 — best fitness -24640937541.88623
#   sample 29/50 (global 28)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 30/50 (global 29)
#     iter 1/15 — best fitness -1833007.77819
#     iter 10/15 — best fitness -145112531886.05859
#     iter 15/15 — best fitness -159227503025.80237
#   sample 31/50 (global 30)
#     iter 1/15 — best fitness -855.46132
#     iter 10/15 — best fitness -54226020083.59338
#     iter 15/15 — best fitness -72699306711.58484
#   sample 32/50 (global 31)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 33/50 (global 32)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -251217130.05013
#     iter 15/15 — best fitness -3447749100.65576
#   sample 34/50 (global 33)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -121040848004.89575
#     iter 15/15 — best fitness -122075117330.71216
#   sample 35/50 (global 34)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -81639638.05204
#     iter 15/15 — best fitness -16684869036.92773
#   sample 36/50 (global 35)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 37/50 (global 36)
#     iter 1/15 — best fitness -866.28402
#     iter 10/15 — best fitness -167486627864.16077
#     iter 15/15 — best fitness -168983686710.90393
#   sample 38/50 (global 37)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 39/50 (global 38)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 40/50 (global 39)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -15421053954.25952
#     iter 15/15 — best fitness -32049210834.95142
#   sample 41/50 (global 40)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -1927.76432
#     iter 15/15 — best fitness -55546.99584
#   sample 42/50 (global 41)
#     iter 1/15 — best fitness -77156.45795
#     iter 10/15 — best fitness -13614788782.32581
#     iter 15/15 — best fitness -37559436097.72266
#   sample 43/50 (global 42)
#     iter 1/15 — best fitness -632650.02612
#     iter 10/15 — best fitness -158476513147.68079
#     iter 15/15 — best fitness -213303068365.28564
#   sample 44/50 (global 43)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -141261986027.13550
#     iter 15/15 — best fitness -207090605079.16479
#   sample 45/50 (global 44)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 46/50 (global 45)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -364010237.27598
#     iter 15/15 — best fitness -905835070.62823
#   sample 47/50 (global 46)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 48/50 (global 47)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 49/50 (global 48)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 50/50 (global 49)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 2/50 (global 51)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 3/50 (global 52)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 4/50 (global 53)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -2121239.32045
#     iter 15/15 — best fitness -62423719.56439
#   sample 5/50 (global 54)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 6/50 (global 55)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -67136967888.66064
#     iter 15/15 — best fitness -88759868836.10767
#   sample 7/50 (global 56)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -24848792.83862
#     iter 15/15 — best fitness -1514215268.73331
#   sample 8/50 (global 57)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 9/50 (global 58)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -3163.90047
#     iter 15/15 — best fitness -19839.48276
#   sample 10/50 (global 59)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 11/50 (global 60)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 12/50 (global 61)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -4221048.32736
#     iter 15/15 — best fitness -539326794.96039
#   sample 13/50 (global 62)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -1065507002.60863
#     iter 15/15 — best fitness -33166936137.34729
#   sample 14/50 (global 63)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 15/50 (global 64)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -762462.39714
#     iter 15/15 — best fitness -249632545.28083
#   sample 16/50 (global 65)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -128305.20043
#   sample 17/50 (global 66)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -210547.60615
#   sample 18/50 (global 67)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -453775.22221
#     iter 15/15 — best fitness -16034652.13785
#   sample 19/50 (global 68)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -296589459.19571
#   sample 20/50 (global 69)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -9118.71600
#     iter 15/15 — best fitness -4101903.63556
#   sample 21/50 (global 70)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -34129.56243
#     iter 15/15 — best fitness -295169.56411
#   sample 22/50 (global 71)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 23/50 (global 72)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -338809506.33132
#     iter 15/15 — best fitness -3361080669.05753
#   sample 24/50 (global 73)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -19202368.53001
#     iter 15/15 — best fitness -34895455.35907
#   sample 25/50 (global 74)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -486555216.08636
#     iter 15/15 — best fitness -55817254265.16833
#   sample 26/50 (global 75)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -9091.97710
#     iter 15/15 — best fitness -10886921.00883
#   sample 27/50 (global 76)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 28/50 (global 77)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -418269913.68599
#     iter 15/15 — best fitness -52396577166.96680
#   sample 29/50 (global 78)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -77082.17380
#     iter 15/15 — best fitness -400076.71861
#   sample 30/50 (global 79)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 31/50 (global 80)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 32/50 (global 81)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -107829883769.18994
#     iter 15/15 — best fitness -124654482066.49573
#   sample 33/50 (global 82)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 34/50 (global 83)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample

#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -80331829336.31921
#     iter 15/15 — best fitness -95463732002.18835
#   sample 7/50 (global 206)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -226664865788.62927
#     iter 15/15 — best fitness -254414652144.93298
#   sample 8/50 (global 207)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 9/50 (global 208)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 10/50 (global 209)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -21976409679.88562
#     iter 15/15 — best fitness -43867495777.52771
#   sample 11/50 (global 210)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -4333356179.14417
#     iter 15/15 — best fitness -48469846951.52917
#   sample 12/50 (global 211)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -304713.47632
#     iter 15/15 — best fitness -52393947.45342
#   sample 13/50 (global 212)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -93180893206.23145
#     iter 15/15 — best fitness -181045816651.99023
#   sample 14/50 (global 213)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 15/50 (global 214)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -367069659.29208
#     iter 15/15 — best fitness -17243009342.19556
#   sample 16/50 (global 215)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 17/50 (global 216)
#     iter 1/15 — best fitness -693438.53520
#     iter 10/15 — best fitness -145938490184.26538
#     iter 15/15 — best fitness -222565229663.53113
#   sample 18/50 (global 217)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 19/50 (global 218)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 20/50 (global 219)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -21174898855.40698
#     iter 15/15 — best fitness -65367420405.63635
#   sample 21/50 (global 220)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -32945.26705
#     iter 15/15 — best fitness -600337.98833
#   sample 22/50 (global 221)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 23/50 (global 222)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 24/50 (global 223)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 25/50 (global 224)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -14653797922.78418
#     iter 15/15 — best fitness -73183329813.15356
#   sample 26/50 (global 225)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -752285652.34629
#     iter 15/15 — best fitness -52003582252.27148
#   sample 27/50 (global 226)
#     iter 1/15 — best fitness -192762.82801
#     iter 10/15 — best fitness -189517668051.64172
#     iter 15/15 — best fitness -189517668051.64172
#   sample 28/50 (global 227)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -65881942015.07935
#     iter 15/15 — best fitness -109129636965.88965
#   sample 29/50 (global 228)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -4321507614.91501
#     iter 15/15 — best fitness -25111497120.90149
#   sample 30/50 (global 229)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 31/50 (global 230)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -72297.60142
#     iter 15/15 — best fitness -272531.92756
#   sample 32/50 (global 231)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 33/50 (global 232)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 34/50 (global 233)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 35/50 (global 234)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 36/50 (global 235)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -73964570242.02747
#     iter 15/15 — best fitness -193175199717.48694
#   sample 37/50 (global 236)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 38/50 (global 237)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 39/50 (global 238)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -440690401.96961
#     iter 15/15 — best fitness -4096111782.42358
#   sample 40/50 (global 239)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 41/50 (global 240)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 42/50 (global 241)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -121086.88684
#   sample 43/50 (global 242)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -135501592.19132
#     iter 15/15 — best fitness -135501592.19132
#   sample 44/50 (global 243)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 45/50 (global 244)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 46/50 (global 245)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 47/50 (global 246)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -126870849813.41833
#     iter 15/15 — best fitness -189929788766.86914
#   sample 48/50 (global 247)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 49/50 (global 248)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 50/50 (global 249)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#
# ── Processing digit 5 (50 samples) ──
#   sample 1/50 (global 250)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -707.53890
#   sample 2/50 (global 251)
#     iter 1/15 — best fitness -8357617.04473
#     iter 10/15 — best fitness -78484414311.28259
#     iter 15/15 — best fitness -128727920709.30090
#   sample 3/50 (global 252)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 4/50 (global 253)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 5/50 (global 254)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 6/50 (global 255)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 7/50 (global 256)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 8/50 (global 257)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 9/50 (global 258)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 10/50 (global 259)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 11/50 (global 260)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 12/50 (global 261)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 13/50 (global 262)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 14/50 (global 263)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 15/50 (global 264)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 16/50 (global 265)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 17/50 (global 266)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 18/50 (global 267)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 19/50 (global 268)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 20/50 (global 269)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 21/50 (global 270)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 22/50 (global 271)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 23/50 (global 272)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -130319795.82558
#     iter 15/15 — best fitness -2267720103.87779
#   sample 24/50 (global 273)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 25/50 (global 274)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 26/50 (global 275)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 27/50 (global 276)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 28/50 (global 277)
#     iter 1/15 — best fitness -14060089.33775
#     iter 10/15 — best fitness -129900577820.35132
#     iter 15/15 — best fitness -193467729842.64673
#   sample 29/50 (global 278)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 30/50 (global 279)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 31/50 (global 280)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 32/50 (global 281)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -1704098.35597
#   sample 33/50 (global 282)
#     iter 1/15 — best fitness -1192.09277
#     iter 10/15 — best fitness -32002512.31757
#     iter 15/15 — best fitness -76819055.58559
#   sample 34/50 (global 283)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -217705.26947
#   sample 35/50 (global 284)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 36/50 (global 285)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 37/50 (global 286)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -60269.10967
#     iter 15/15 — best fitness -60269.10967
#   sample 38/50 (global 287)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -32305404.71598
#     iter 15/15 — best fitness -51220629915.41760
#   sample 39/50 (global 288)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 40/50 (global 289)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 41/50 (global 290)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 42/50 (global 291)
#     iter 1/15 — best fitness -3210.88350
#     iter 10/15 — best fitness -76105197249.33191
#     iter 15/15 — best fitness -92911651887.51953
#   sample 43/50 (global 292)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 44/50 (global 293)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 45/50 (global 294)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -4260356.73256
#     iter 15/15 — best fitness -6709941.88952
#   sample 46/50 (global 295)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 47/50 (global 296)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 48/50 (global 297)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -172412.11048
#   sample 49/50 (global 298)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 50/50 (global 299)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#
# ── Processing digit 6 (50 samples) ──
#   sample 1/50 (global 300)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 2/50 (global 301)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -16793890.70735
#     iter 15/15 — best fitness -372933037.88948
#   sample 3/50 (global 302)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 4/50 (global 303)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -181302467.48006
#     iter 15/15 — best fitness -1272135486.16113
#   sample 5/50 (global 304)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 6/50 (global 305)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 7/50 (global 306)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 8/50 (global 307)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 9/50 (global 308)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 10/50 (global 309)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 11/50 (global 310)
#     iter 1/15 — best fitness -16821436.06819
#     iter 10/15 — best fitness -78703439952.82031
#     iter 15/15 — best fitness -97919386137.54834
#   sample 12/50 (global 311)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
# ...
#   sample 8/50 (global 407)
#     iter 1/15 — best fitness -2356152.02435
#     iter 10/15 — best fitness -155238998653.06042
#     iter 15/15 — best fitness -186002977576.98193
#   sample 9/50 (global 408)
#     iter 1/15 — best fitness -51276116004.69299
#     iter 10/15 — best fitness -461292036265.27319
#     iter 15/15 — best fitness -476661756701.07800
#   sample 10/50 (global 409)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 11/50 (global 410)
#     iter 1/15 — best fitness -840.64269
#     iter 10/15 — best fitness -160575369120.86682
#     iter 15/15 — best fitness -186195257401.41663
#   sample 12/50 (global 411)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -40481351113.72034
#     iter 15/15 — best fitness -79410780125.00305
#   sample 13/50 (global 412)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -178774636.76318
#     iter 15/15 — best fitness -14193103974.23694
#   sample 14/50 (global 413)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -326774845.94897
#     iter 15/15 — best fitness -52519992143.31641
#   sample 15/50 (global 414)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness -10.00000
#   sample 16/50 (global 415)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -117624989.53958
#     iter 15/15 — best fitness -83890617609.53491
#   sample 17/50 (global 416)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -10.00000
#     iter 15/15 — best fitness

#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -3533464.47633
#     iter 15/15 — best fitness -25398131.12507
#   sample 48/50 (global 497)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -3627570.21552
#     iter 15/15 — best fitness -550910999.75117
#   sample 49/50 (global 498)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -5516.97185
#     iter 15/15 — best fitness -9306641.51948
#   sample 50/50 (global 499)
#     iter 1/15 — best fitness -10.00000
#     iter 10/15 — best fitness -116302459974.81421
#     iter 15/15 — best fitness -186004617937.28931
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 132
# Detailed results  CSV    : Generated Data/LQ-cnn_ZC-CSA_images\LQ_cnn_zc_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/LQ-cnn_ZC-CSA_images\LQ_cnn_zc_csa_stats_per_digit.csv
# Total time               : 135.57 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   32             18     50       64.0      36.0
# 1                   45              5     50       90.0      10.0
# 2                   41              9     50       82.0      18.0
# 3                   39             11     50       78.0      22.0
# 4                   34             16     50       68.0      32.0
# 5                   46              4     50       92.0       8.0
# 6                   45              5     50       90.0      10.0
# 7                   36             14     50       72.0      28.0
# 8                   29             21     50       58.0      42.0
# 9                   21             29     50       42.0      58.0

# %% [markdown]
# ### Low Magnitude

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 5.0
raw_lower_bound  = -80.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = True           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-10
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "CNN.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e10,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "CNN_500_samples_test.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/LM-cnn_ZC-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "LM_cnn_zc_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "LM_cnn_zc_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\CNN.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 5/50 (global 4)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 6/50 (global 5)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 7/50 (global 6)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 8/50 (global 7)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 9/50 (global 8)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 10/50 (global 9)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 11/50 (global 10)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 12/50 (global 11)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 13/50 (global 12)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 14/50 (global 13)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 15/50 (global 14)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 16/50 (global 15)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 17/50 (global 16)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 18/50 (global 17)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 19/50 (global 18)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 20/50 (global 19)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 21/50 (global 20)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 22/50 (global 21)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 23/50 (global 22)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -175652684.21535
#     iter 20/100 — best fitness -1895365410.80284
#     iter 30/100 — best fitness -7569042288.05835
#     iter 40/100 — best fitness -9027536951.97144
#     iter 50/100 — best fitness -21680546837.63147
#     iter 60/100 — best fitness -29831088618.02490
#     iter 70/100 — best fitness -37015443865.60620
#     iter 80/100 — best fitness -63327854754.70435
#     iter 90/100 — best fitness -70836475967.18372
#     iter 100/100 — best fitness -78392866726.64563
#   sample 24/50 (global 23)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 25/50 (global 24)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 26/50 (global 25)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 27/50 (global 26)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 28/50 (global 27)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -13031.71780
#     iter 50/100 — best fitness -54751.66530
#     iter 60/100 — best fitness -1370719.61766
#     iter 70/100 — best fitness -3828173.14231
#     iter 80/100 — best fitness -11142130.61697
#     iter 90/100 — best fitness -128900980.27801
#     iter 100/100 — best fitness -228907177.85309
#   sample 29/50 (global 28)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 30/50 (global 29)
#     iter 1/100 — best fitness -160741.40423
#     iter 10/100 — best fitness -2133333613.79846
#     iter 20/100 — best fitness -22725251848.00049
#     iter 30/100 — best fitness -28698893714.93652
#     iter 40/100 — best fitness -35396824991.07092
#     iter 50/100 — best fitness -51039990049.85388
#     iter 60/100 — best fitness -54430798151.63342
#     iter 70/100 — best fitness -61769913281.77112
#     iter 80/100 — best fitness -70355766851.26331
#     iter 90/100 — best fitness -77541855409.48938
#     iter 100/100 — best fitness -78907073570.16882
#   sample 31/50 (global 30)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -21362017.81825
#     iter 20/100 — best fitness -1034212453.38579
#     iter 30/100 — best fitness -8336996908.09412
#     iter 40/100 — best fitness -12691179392.66443
#     iter 50/100 — best fitness -22349542247.63660
#     iter 60/100 — best fitness -34318452941.75085
#     iter 70/100 — best fitness -40265143972.15295
#     iter 80/100 — best fitness -47593082051.90027
#     iter 90/100 — best fitness -60888203234.68896
#     iter 100/100 — best fitness -64286783781.95288
#   sample 32/50 (global 31)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 33/50 (global 32)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 34/50 (global 33)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1123.75167
#     iter 20/100 — best fitness -23804.21011
#     iter 30/100 — best fitness -207337.46052
#     iter 40/100 — best fitness -256214.83128
#     iter 50/100 — best fitness -3322892.31191
#     iter 60/100 — best fitness -22987987.86246
#     iter 70/100 — best fitness -46186794.55888
#     iter 80/100 — best fitness -85440682.02313
#     iter 90/100 — best fitness -244202770.10723
#     iter 100/100 — best fitness -310501946.28076
#   sample 35/50 (global 34)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 36/50 (global 35)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 37/50 (global 36)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -19545419.81290
#     iter 20/100 — best fitness -62130300.26706
#     iter 30/100 — best fitness -2466053700.81566
#     iter 40/100 — best fitness -12459798929.94006
#     iter 50/100 — best fitness -51427639546.59692
#     iter 60/100 — best fitness -63869708594.69458
#     iter 70/100 — best fitness -72700546800.94946
#     iter 80/100 — best fitness -87451828575.18970
#     iter 90/100 — best fitness -111229866604.58679
#     iter 100/100 — best fitness -127857702827.01489
#   sample 38/50 (global 37)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 39/50 (global 38)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 40/50 (global 39)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -421883.05484
#     iter 20/100 — best fitness -3007060.63588
#     iter 30/100 — best fitness -6842512.80380
#     iter 40/100 — best fitness -83503246.49317
#     iter 50/100 — best fitness -158097701.31133
#     iter 60/100 — best fitness -203156446.38334
#     iter 70/100 — best fitness -223204623.97985
#     iter 80/100 — best fitness -455856189.83130
#     iter 90/100 — best fitness -1327507802.67644
#     iter 100/100 — best fitness -4510636787.02448
#   sample 41/50 (global 40)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 42/50 (global 41)
#     iter 1/100 — best fitness -43872.78136
#     iter 10/100 — best fitness -19074096562.42212
#     iter 20/100 — best fitness -26637486088.62927
#     iter 30/100 — best fitness -30064505259.24182
#     iter 40/100 — best fitness -44704893742.29846
#     iter 50/100 — best fitness -47096022226.33069
#     iter 60/100 — best fitness -65397623659.26453
#     iter 70/100 — best fitness -71866840004.34753
#     iter 80/100 — best fitness -88451555845.02246
#     iter 90/100 — best fitness -88934239027.60388
#     iter 100/100 — best fitness -100669087046.55652
#   sample 43/50 (global 42)
#     iter 1/100 — best fitness -4572.46793
#     iter 10/100 — best fitness -1265840872.85381
#     iter 20/100 — best fitness -2402899896.54732
#     iter 30/100 — best fitness -8357290514.18182
#     iter 40/100 — best fitness -20555709448.01123
#     iter 50/100 — best fitness -36842151734.78235
#     iter 60/100 — best fitness -59380911463.43115
#     iter 70/100 — best fitness -65678599949.52356
#     iter 80/100 — best fitness -75642155286.63281
#     iter 90/100 — best fitness -90025757436.54932
#     iter 100/100 — best fitness -93359488132.29089
#   sample 44/50 (global 43)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1327834.07112
#     iter 20/100 — best fitness -108911496.90287
#     iter 30/100 — best fitness -555228075.52929
#     iter 40/100 — best fitness -1818864515.41934
#     iter 50/100 — best fitness -2432912610.50929
#     iter 60/100 — best fitness -2749217314.93930
#     iter 70/100 — best fitness -6244987720.61505
#     iter 80/100 — best fitness -10112050641.38232
#     iter 90/100 — best fitness -22721198681.62000
#     iter 100/100 — best fitness -24591804625.85205
#   sample 45/50 (global 44)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 46/50 (global 45)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 47/50 (global 46)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 48/50 (global 47)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 49/50 (global 48)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 50/50 (global 49)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 2/50 (global 51)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 3/50 (global 52)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 4/50 (global 53)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 5/50 (global 54)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 6/50 (global 55)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness

#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -24434174.39062
#     iter 20/100 — best fitness -3715054268.72516
#     iter 30/100 — best fitness -22379490003.94348
#     iter 40/100 — best fitness -28238991355.02905
#     iter 50/100 — best fitness -49557369773.47607
#     iter 60/100 — best fitness -52275970994.65063
#     iter 70/100 — best fitness -65867441785.90576
#     iter 80/100 — best fitness -82900932927.20923
#     iter 90/100 — best fitness -96539467468.88879
#     iter 100/100 — best fitness -100355356770.20300
#   sample 35/50 (global 484)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 36/50 (global 485)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 37/50 (global 486)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 38/50 (global 487)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -70253.14292
#     iter 30/100 — best fitness -912989.29777
#     iter 40/100 — best fitness -2893865.33782
#     iter 50/100 — best fitness -3266876.64039
#     iter 60/100 — best fitness -8347000.64148
#     iter 70/100 — best fitness -32254711.08860
#     iter 80/100 — best fitness -115297044.97865
#     iter 90/100 — best fitness -333327595.50611
#     iter 100/100 — best fitness -519935104.72498
#   sample 39/50 (global 488)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 40/50 (global 489)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 41/50 (global 490)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 42/50 (global 491)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -4687.35718
#     iter 80/100 — best fitness -92889.64541
#     iter 90/100 — best fitness -169180.98902
#     iter 100/100 — best fitness -762811.60063
#   sample 43/50 (global 492)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 44/50 (global 493)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 45/50 (global 494)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 46/50 (global 495)
#     iter 1/100 — best fitness -3387.98384
#     iter 10/100 — best fitness -703785189.05894
#     iter 20/100 — best fitness -6750385656.77502
#     iter 30/100 — best fitness -32118834179.75842
#     iter 40/100 — best fitness -53678353931.71387
#     iter 50/100 — best fitness -64875119828.65186
#     iter 60/100 — best fitness -71469138685.18530
#     iter 70/100 — best fitness -93791521615.05847
#     iter 80/100 — best fitness -103707836696.64038
#     iter 90/100 — best fitness -106028383797.73804
#     iter 100/100 — best fitness -107685745783.06262
#   sample 47/50 (global 496)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 48/50 (global 497)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -1.00000
#     iter 10/100 — best fitness -1.00000
#     iter 20/100 — best fitness -1.00000
#     iter 30/100 — best fitness -1.00000
#     iter 40/100 — best fitness -1.00000
#     iter 50/100 — best fitness -1.00000
#     iter 60/100 — best fitness -1.00000
#     iter 70/100 — best fitness -1.00000
#     iter 80/100 — best fitness -1.00000
#     iter 90/100 — best fitness -1.00000
#     iter 100/100 — best fitness -1.00000
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 63
# Detailed results  CSV    : Generated Data/LM-cnn_ZC-CSA_images\LM_cnn_zc_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/LM-cnn_ZC-CSA_images\LM_cnn_zc_csa_stats_per_digit.csv
# Total time               : 9783.45 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   43              7     50       86.0      14.0
# 1                   49              1     50       98.0       2.0
# 2                   42              8     50       84.0      16.0
# 3                   48              2     50       96.0       4.0
# 4                   41              9     50       82.0      18.0
# 5                   43              7     50       86.0      14.0
# 6                   45              5     50       90.0      10.0
# 7                   45              5     50       90.0      10.0
# 8                   40             10     50       80.0      20.0
# 9                   41              9     50       82.0      18.0
