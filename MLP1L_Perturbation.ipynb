# %% [markdown]
# ## Perturbation on 500 Samples from train/seen set

# %% [markdown]
# #### ZC-CSA

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = False           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "MainModel_MLP1L.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e9,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "MLP1L_500_samples_train.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/ZC-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "zc_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "zc_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\MainModel_MLP1L.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -903.91118
#     iter 10/100 — best fitness -1802411.84462
#     iter 20/100 — best fitness -145407818.11292
#     iter 30/100 — best fitness -1312163384.78008
#     iter 40/100 — best fitness -14319328344.32617
#     iter 50/100 — best fitness -31501459140.51117
#     iter 60/100 — best fitness -47593087202.54749
#     iter 70/100 — best fitness -58469551834.54590
#     iter 80/100 — best fitness -63339175016.89343
#     iter 90/100 — best fitness -70574511316.90576
#     iter 100/100 — best fitness -78691944099.71393
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -4625575.34420
#     iter 20/100 — best fitness -19042323.22815
#     iter 30/100 — best fitness -154505476.31606
#     iter 40/100 — best fitness -425878196.88104
#     iter 50/100 — best fitness -1410581643.57906
#     iter 60/100 — best fitness -2704317590.38513
#     iter 70/100 — best fitness -7148417253.25427
#     iter 80/100 — best fitness -11673222785.33777
#     iter 90/100 — best fitness -16789864321.07947
#     iter 100/100 — best fitness -21802524347.64722
#   sample 5/50 (global 4)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 6/50 (global 5)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 7/50 (global 6)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 8/50 (global 7)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -57925134.68433
#     iter 20/100 — best fitness -5193236604.15704
#     iter 30/100 — best fitness -35713032605.11121
#     iter 40/100 — best fitness -73518728104.46204
#     iter 50/100 — best fitness -104754103462.87488
#     iter 60/100 — best fitness -135653609110.12622
#     iter 70/100 — best fitness -163734911744.76465
#     iter 80/100 — best fitness -183003348128.50098
#     iter 90/100 — best fitness -211638315965.40796
#     iter 100/100 — best fitness -215605391263.20215
#   sample 9/50 (global 8)
#     iter 1/100 — best fitness -3381.90406
#     iter 10/100 — best fitness -66878184152.91431
#     iter 20/100 — best fitness -105941637863.84583
#     iter 30/100 — best fitness -135680626704.81323
#     iter 40/100 — best fitness -157214087328.53943
#     iter 50/100 — best fitness -165952948391.59937
#     iter 60/100 — best fitness -179199293903.83594
#     iter 70/100 — best fitness -214558428565.01050
#     iter 80/100 — best fitness -224549216070.37183
#     iter 90/100 — best fitness -239935683054.34241
#     iter 100/100 — best fitness -241607283397.04675
#   sample 10/50 (global 9)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 11/50 (global 10)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 12/50 (global 11)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -7234553266.07458
#     iter 20/100 — best fitness -46659997793.21899
#     iter 30/100 — best fitness -63308910237.44373
#     iter 40/100 — best fitness -80455158996.28955
#     iter 50/100 — best fitness -91662939822.85767
#     iter 60/100 — best fitness -100595015355.30432
#     iter 70/100 — best fitness -115232085050.52258
#     iter 80/100 — best fitness -128462179956.41528
#     iter 90/100 — best fitness -135723446611.33167
#     iter 100/100 — best fitness -149222077184.84741
#   sample 13/50 (global 12)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 14/50 (global 13)
#     iter 1/100 — best fitness -174494061.43162
#     iter 10/100 — best fitness -37114905232.31665
#     iter 20/100 — best fitness -55699542905.56738
#     iter 30/100 — best fitness -78517483543.42053
#     iter 40/100 — best fitness -104917858894.43054
#     iter 50/100 — best fitness -120332888456.70789
#     iter 60/100 — best fitness -143482579082.17737
#     iter 70/100 — best fitness -178554953418.69092
#     iter 80/100 — best fitness -185909937694.80872
#     iter 90/100 — best fitness -192691401312.26318
#     iter 100/100 — best fitness -200621603792.70740
#   sample 15/50 (global 14)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 16/50 (global 15)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -767384244.16149
#     iter 20/100 — best fitness -33503416905.16443
#     iter 30/100 — best fitness -45669907448.45508
#     iter 40/100 — best fitness -59464520322.99194
#     iter 50/100 — best fitness -74785970553.39624
#     iter 60/100 — best fitness -111039723248.03784
#     iter 70/100 — best fitness -125993832428.81458
#     iter 80/100 — best fitness -132048214753.98743
#     iter 90/100 — best fitness -140213440731.70410
#     iter 100/100 — best fitness -146676939799.72278
#   sample 17/50 (global 16)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -1373.37411
#     iter 20/100 — best fitness -43063.62130
#     iter 30/100 — best fitness -1102756.10744
#     iter 40/100 — best fitness -7337149.32174
#     iter 50/100 — best fitness -21309897.53130
#     iter 60/100 — best fitness -491853663.56572
#     iter 70/100 — best fitness -899464897.56796
#     iter 80/100 — best fitness -3045263696.11807
#     iter 90/100 — best fitness -3350244573.16757
#     iter 100/100 — best fitness -4316405463.89456
#   sample 18/50 (global 17)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample

#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -20992750060.65930
#     iter 20/100 — best fitness -60028590061.86548
#     iter 30/100 — best fitness -88114174675.07874
#     iter 40/100 — best fitness -95051401931.04688
#     iter 50/100 — best fitness -119352358647.67737
#     iter 60/100 — best fitness -133374346552.71289
#     iter 70/100 — best fitness -152696665563.62524
#     iter 80/100 — best fitness -177417506007.12964
#     iter 90/100 — best fitness -182936495571.31995
#     iter 100/100 — best fitness -197473105218.78394
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 290
# Detailed results  CSV    : Generated Data/ZC-CSA_images\zc_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/ZC-CSA_images\zc_csa_stats_per_digit.csv
# Total time               : 7047.83 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   31             19     50       62.0      38.0
# 1                    3             47     50        6.0      94.0
# 2                   35             15     50       70.0      30.0
# 3                   29             21     50       58.0      42.0
# 4                   11             39     50       22.0      78.0
# 5                   31             19     50       62.0      38.0
# 6                   26             24     50       52.0      48.0
# 7                   32             18     50       64.0      36.0
# 8                   11             39     50       22.0      78.0
# 9                    1             49     50        2.0      98.0

# %% [markdown]
# #### C-CSA

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = False           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "MainModel_MLP1L.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e9,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.empty((n_nests, dim), dtype=torch.float32, device=device) \
                 .uniform_(float(self.raw_lower), float(self.raw_upper))

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "MLP1L_500_samples_train.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/C-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "c_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "c_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\MainModel_MLP1L.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness 945.98315
#     iter 10/100 — best fitness 945.98315
#     iter 20/100 — best fitness 945.98315
#     iter 30/100 — best fitness 945.98315
#     iter 40/100 — best fitness 945.98315
#     iter 50/100 — best fitness 945.90131
#     iter 60/100 — best fitness 943.82111
#     iter 70/100 — best fitness 943.56244
#     iter 80/100 — best fitness 943.15387
#     iter 90/100 — best fitness 939.54785
#     iter 100/100 — best fitness 932.88245
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -183771.75000
#     iter 10/100 — best fitness -5917102.82177
#     iter 20/100 — best fitness -421301917.12657
#     iter 30/100 — best fitness -6677506660.84222
#     iter 40/100 — best fitness -15847215731.68091
#     iter 50/100 — best fitness -37797094648.76611
#     iter 60/100 — best fitness -61287201691.44055
#     iter 70/100 — best fitness -75748099137.09521
#     iter 80/100 — best fitness -103976324836.71753
#     iter 90/100 — best fitness -117696265020.07129
#     iter 100/100 — best fitness -131219195164.71472
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness 941.84827
#     iter 10/100 — best fitness 941.84827
#     iter 20/100 — best fitness 941.84827
#     iter 30/100 — best fitness 941.84827
#     iter 40/100 — best fitness 941.84827
#     iter 50/100 — best fitness 939.21722
#     iter 60/100 — best fitness 937.85498
#     iter 70/100 — best fitness 937.80866
#     iter 80/100 — best fitness 935.32343
#     iter 90/100 — best fitness 933.04834
#     iter 100/100 — best fitness 930.96960
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -300569.09375
#     iter 10/100 — best fitness -3105075.91613
#     iter 20/100 — best fitness -80877536.74252
#     iter 30/100 — best fitness -122872824.78028
#     iter 40/100 — best fitness -618359544.66583
#     iter 50/100 — best fitness -1637096642.03664
#     iter 60/100 — best fitness -3917984735.43674
#     iter 70/100 — best fitness -9910421432.48279
#     iter 80/100 — best fitness -19979873959.04688
#     iter 90/100 — best fitness -25606352154.04443
#     iter 100/100 — best fitness -30458167848.87439
#   sample 5/50 (global 4)
#     iter 1/100 — best fitness 947.94672
#     iter 10/100 — best fitness 947.94672
#     iter 20/100 — best fitness 947.94672
#     iter 30/100 — best fitness 947.94672
#     iter 40/100 — best fitness 941.24542
#     iter 50/100 — best fitness 940.84833
#     iter 60/100 — best fitness 937.33319
#     iter 70/100 — best fitness 937.33319
#     iter 80/100 — best fitness 936.09973
#     iter 90/100 — best fitness 935.41138
#     iter 100/100 — best fitness 932.07379
#   sample 6/50 (global 5)
#     iter 1/100 — best fitness 954.57178
#     iter 10/100 — best fitness 954.57178
#     iter 20/100 — best fitness 954.57178
#     iter 30/100 — best fitness 950.80219
#     iter 40/100 — best fitness 947.02496
#     iter 50/100 — best fitness 945.30060
#     iter 60/100 — best fitness 944.83649
#     iter 70/100 — best fitness 941.65942
#     iter 80/100 — best fitness 938.61420
#     iter 90/100 — best fitness 934.78809
#     iter 100/100 — best fitness 929.78033
#   sample 7/50 (global 6)
#     iter 1/100 — best fitness 974.02783
#     iter 10/100 — best fitness 970.45538
#     iter 20/100 — best fitness 945.58679
#     iter 30/100 — best fitness 945.58679
#     iter 40/100 — best fitness 940.56055
#     iter 50/100 — best fitness 937.89197
#     iter 60/100 — best fitness 937.89197
#     iter 70/100 — best fitness 937.51416
#     iter 80/100 — best fitness 935.47797
#     iter 90/100 — best fitness 932.57129
#     iter 100/100 — best fitness 930.00177
#   sample 8/50 (global 7)
#     iter 1/100 — best fitness -1702327.25481
#     iter 10/100 — best fitness -376248757.35296
#     iter 20/100 — best fitness -7681494491.62738
#     iter 30/100 — best fitness -41348332259.08167
#     iter 40/100 — best fitness -63819702980.38525
#     iter 50/100 — best fitness -111989897585.98779
#     iter 60/100 — best fitness -122356413662.26233
#     iter 70/100 — best fitness -162361735157.54907
#     iter 80/100 — best fitness -183919333266.98792
#     iter 90/100 — best fitness -197665232460.33923
#     iter 100/100 — best fitness -197952135841.06738
#   sample 9/50 (global 8)
#     iter 1/100 — best fitness -13526811752.35889
#     iter 10/100 — best fitness -86600655452.18823
#     iter 20/100 — best fitness -107494934883.69666
#     iter 30/100 — best fitness -143194216565.80005
#     iter 40/100 — best fitness -181803320705.25769
#     iter 50/100 — best fitness -205220793527.85742
#     iter 60/100 — best fitness -226103762417.94226
#     iter 70/100 — best fitness -233712233336.70703
#     iter 80/100 — best fitness -241507490909.77710
#     iter 90/100 — best fitness -242968920508.81055
#     iter 100/100 — best fitness -250277746955.65735
#   sample 10/50 (global 9)
#     iter 1/100 — best fitness 955.77783
#     iter 10/100 — best fitness 955.77783
#     iter 20/100 — best fitness 955.77783
#     iter 30/100 — best fitness 952.16644
#     iter 40/100 — best fitness 952.16644
#     iter 50/100 — best fitness 939.56116
#     iter 60/100 — best fitness 936.30634
#     iter 70/100 — best fitness 936.30634
#     iter 80/100 — best fitness 935.97272
#     iter 90/100 — best fitness 933.71527
#     iter 100/100 — best fitness 932.28790
#   sample 11/50 (global 10)
#     iter 1/100 — best fitness 954.18719
#     iter 10/100 — best fitness 954.18719
#     iter 20/100 — best fitness 951.35883
#     iter 30/100 — best fitness 948.68817
#     iter 40/100 — best fitness 948.68817
#     iter 50/100 — best fitness 948.44720
#     iter 60/100 — best fitness 943.93048
#     iter 70/100 — best fitness 940.42773
#     iter 80/100 — best fitness 939.19922
#     iter 90/100 — best fitness 937.23334
#     iter 100/100 — best fitness 932.53833
#   sample 12/50 (global 11)
#     iter 1/100 — best fitness -91030048.00000
#     iter 10/100 — best fitness -18122030600.88281
#     iter 20/100 — best fitness -32534936781.13928
#     iter 30/100 — best fitness -80452422016.79822
#     iter 40/100 — best fitness -91438187469.21545
#     iter 50/100 — best fitness -120748490181.80933
#     iter 60/100 — best fitness -128180998644.38696
#     iter 70/100 — best fitness -144685677352.22437
#     iter 80/100 — best fitness -147112263498.32458
#     iter 90/100 — best fitness -151668099228.06995
#     iter 100/100 — best fitness -163677634034.47070
#   sample 13/50 (global 12)
#     iter 1/100 — best fitness 928.66724
#     iter 10/100 — best fitness 928.66724
#     iter 20/100 — best fitness 928.66724
#     iter 30/100 — best fitness 928.66724
#     iter 40/100 — best fitness 928.66724
#     iter 50/100 — best fitness 928.66724
#     iter 60/100 — best fitness 925.03345
#     iter 70/100 — best fitness 925.03345
#     iter 80/100 — best fitness 923.68555
#     iter 90/100 — best fitness 923.03833
#     iter 100/100 — best fitness 919.46442
#   sample 14/50 (global 13)
#     iter 1/100 — best fitness -4232119808.00000
#     iter 10/100 — best fitness -40079950202.44958
#     iter 20/100 — best fitness -67679923835.02393
#     iter 30/100 — best fitness -106033142848.56262
#     iter 40/100 — best fitness -114469984834.48486
#     iter 50/100 — best fitness -128496197496.47412
#     iter 60/100 — best fitness -131738404068.15955
#     iter 70/100 — best fitness -143188189338.94470
#     iter 80/100 — best fitness -159717816172.09497
#     iter 90/100 — best fitness -172891272364.79907
#     iter 100/100 — best fitness -182824019250.33911
#   sample 15/50 (global 14)
#     iter 1/100 — best fitness 963.44348
#     iter 10/100 — best fitness 960.48840
#     iter 20/100 — best fitness 960.48840
#     iter 30/100 — best fitness 941.85742
#     iter 40/100 — best fitness 941.85742
#     iter 50/100 — best fitness 941.85742
#     iter 60/100 — best fitness 940.54742
#     iter 70/100 — best fitness 937.49530
#     iter 80/100 — best fitness 937.17865
#     iter 90/100 — best fitness 937.01459
#     iter 100/100 — best fitness 935.73352
#   sample 16/50 (global 15)
#     iter 1/100 — best fitness -7108473.55886
#     iter 10/100 — best fitness -618469392.51534
#     iter 20/100 — best fitness -7062504390.22705
#     iter 30/100 — best fitness -28573437989.81897
#     iter 40/100 — best fitness -47814072452.46118
#     iter 50/100 — best fitness -72692626777.98730
#     iter 60/100 — best fitness -94983242808.85327
#     iter 70/100 — best fitness -116049574655.84583
#     iter 80/100 — best fitness -134825362008.53149
#     iter 90/100 — best fitness -154066284942.24756
#     iter 100/100 — best fitness -160539015584.00806
#   sample 17/50 (global 16)
#     iter 1/100 — best fitness 954.21191
#     iter 10/100 — best fitness 949.57813
#     iter 20/100 — best fitness -40694.64333
#     iter 30/100 — best fitness -648614.67047
#     iter 40/100 — best fitness -2989429.15472
#     iter 50/100 — best fitness -74633167.51691
#     iter 60/100 — best fitness -502033953.88734
#     iter 70/100 — best fitness -1043797781.19958
#     iter 80/100 — best fitness -3552729532.44623
#     iter 90/100 — best fitness -8941985405.77039
#     iter 100/100 — best fitness -12714995181.43518
#   sample 18/50 (global 17)
#     iter 1/100 — best fitness 953.88269
#     iter 10/100 — best fitness 953.88269
#     iter 20/100 — best fitness 953.88269
#     iter 30/100 — best fitness 944.96094
#     iter 40/100 — best fitness 944.96094
#     iter 50/100 — best fitness 944.96094
#     iter 60/100 — best fitness 943.85510
#     iter 70/100 — best fitness 938.79480
#     iter 80/100 — best fitness 934.68512
#     iter 90/100 — best fitness 934.44684
#     iter 100/100 — best fitness 930.23322
#   sample 19/50 (global 18)
#     iter 1/100 — best fitness 969.24207
#     iter 10/100 — best fitness 969.24207
#     iter 20/100 — best fitness 964.98505
#     iter 30/100 — best fitness 946.48535
#     iter 40/100 — best fitness 942.71112
#     iter 50/100 — best fitness 938.19928
#     iter 60/100 — best fitness 936.92584
#     iter 70/100 — best fitness 936.92584
#     iter 80/100 — best fitness 932.99701
#     iter 90/100 — best fitness 932.26880
#     iter 100/100 — best fitness 932.26880
#   sample 20/50 (global 19)
#     iter 1/100 — best fitness 949.09570
#     iter 10/100 — best fitness 949.09570
#     iter 20/100 — best fitness 943.63092
#     iter 30/100 — best fitness 943.63092
#     iter 40/100 — best fitness 943.63092
#     iter 50/100 — best fitness 942.11585
#     iter 60/100 — best fitness 942.11585
#     iter 70/100 — best fitness 937.37439
#     iter 80/100 — best fitness 930.79456
#     iter 90/100 — best fitness 928.39624
#     iter 100/100 — best fitness 922.71637
#   sample 21/50 (global 20)
#     iter 1/100 — best fitness -2100788803.60452
#     iter 10/100 — best fitness -32112428044.27771
#     iter 20/100 — best fitness -48452361897.29932
#     iter 30/100 — best fitness -66731685497.88574
#     iter 40/100 — best fitness -97026823851.30518
#     iter 50/100 — best fitness -109818180872.19202
#     iter 60/100 — best fitness -127260111637.06824
#     iter 70/100 — best fitness -135966337973.75476
#     iter 80/100 — best fitness -151377829352.46301
#     iter 90/100 — best fitness -162033442298.39490
#     iter 100/100 — best fitness -167978171142.77795
#   sample 22/50 (global 21)
#     iter 1/100 — best fitness -91658677026.36792
#     iter 10/100 — best fitness -117771901040.53882
#     iter 20/100 — best fitness -140475472337.79309
#     iter 30/100 — best fitness -185798453193.42114
#     iter 40/100 — best fitness -196915663555.39136
#     iter 50/100 — best fitness -202760199379.19714
#     iter 60/100 — best fitness -208557242228.63159
#     iter 70/100 — best fitness -233634909411.85486
#     iter 80/100 — best fitness -253064116259.26904
#     iter 90/100 — best fitness -266470011487.58545
#     iter 100/100 — best fitness -269151800885.48157
#   sample 23/50 (global 22)
#     iter 1/100 — best fitness 960.13531
#     iter 10/100 — best fitness 960.13531
#     iter 20/100 — best fitness 960.13531
#     iter 30/100 — best fitness 958.07275
#     iter 40/100 — best fitness 931.14093
#     iter 50/100 — best fitness 931.12799
#     iter 60/100 — best fitness 930.45313
#     iter 70/100 — best fitness 930.45313
#     iter 80/100 — best fitness 928.27771
#     iter 90/100 — best fitness 928.27771
#     iter 100/100 — best fitness 927.15668
#   sample 24/50 (global 23)
#     iter 1/100 — best fitness -83629.25510
#     iter 10/100 — best fitness -4153681.42419
#     iter 20/100 — best fitness -18798406.31031
#     iter 30/100 — best fitness -1233296678.46620
#     iter 40/100 — best fitness -1954700768.55148
#     iter 50/100 — best fitness -3900598700.27908
#     iter 60/100 — best fitness -17154821250.72021
#     iter 70/100 — best fitness -18895504569.94214
#     iter 80/100 — best fitness -26561185210.41663
#     iter 90/100 — best fitness -34988290108.57935
#     iter 100/100 — best fitness -45605372233.68164
#   sample 25/50 (global 24)
#     iter 1/100 — best fitness 950.39862
#     iter 10/100 — best fitness 950.39862
#     iter 20/100 — best fitness 950.39862
#     iter 30/100 — best fitness 945.46155
#     iter 40/100 — best fitness 945.46155
#     iter 50/100 — best fitness 944.48016
#     iter 60/100 — best fitness 940.52856
#     iter 70/100 — best fitness 940.51569
#     iter 80/100 — best fitness 938.21228
#     iter 90/100 — best fitness 933.92456
#     iter 100/100 — best fitness 933.53906
#   sample 26/50 (global 25)
#     iter 1/100 — best fitness 951.80054
#     iter 10/100 — best fitness 951.80054
#     iter 20/100 — best fitness 951.80054
#     iter 30/100 — best fitness 950.45807
#     iter 40/100 — best fitness 947.52997
#     iter 50/100 — best fitness 945.12238
#     iter 60/100 — best fitness 930.76227
#     iter 70/100 — best fitness 930.76227
#     iter 80/100 — best fitness 930.41888
#     iter 90/100 — best fitness 928.76477
#     iter 100/100 — best fitness 925.34912
#   sample 27/50 (global 26)
#     iter 1/100 — best fitness 962.85608
#     iter 10/100 — best fitness 961.43823
#     iter 20/100 — best fitness 954.66534
#     iter 30/100 — best fitness 950.01312
#     iter 40/100 — best fitness 947.15106
#     iter 50/100 — best fitness 946.77649
#     iter 60/100 — best fitness 935.92462
#     iter 70/100 — best fitness 934.52539
#     iter 80/100 — best fitness 934.52539
#     iter 90/100 — best fitness 933.42676
#     iter 100/100 — best fitness 930.24652
#   sample 28/50 (global 27)
#     iter 1/100 — best fitness 952.80231
#     iter 10/100 — best fitness 952.80231
#     iter 20/100 — best fitness 952.80231
#     iter 30/100 — best fitness 952.80231
#     iter 40/100 — best fitness 952.80231
#     iter 50/100 — best fitness 931.14575
#     iter 60/100 — best fitness 929.37402
#     iter 70/100 — best fitness 929.37402
#     iter 80/100 — best fitness 921.52210
#     iter 90/100 — best fitness 920.20282
#     iter 100/100 — best fitness 918.61743
#   sample 29/50 (global 28)
#     iter 1/100 — best fitness -322397146.13119
#     iter 10/100 — best fitness -36641534685.71814
#     iter 20/100 — best fitness -72092279287.54199
#     iter 30/100 — best fitness -99489373036.91431
#     iter 40/100 — best fitness -127418507395.23718
#     iter 50/100 — best fitness -155148733900.42749
#     iter 60/100 — best fitness -175925864024.65222
#     iter 70/100 — best fitness -188663729465.95581
#     iter 80/100 — best fitness -202745341089.58032
#     iter 90/100 — best fitness -220430220437.55688
#     iter 100/100 — best fitness -224036921334.07593
#   sample 30/50 (global 29)
#     iter 1/100 — best fitness 975.03674
#     iter 10/100 — best fitness -164.02251
#     iter 20/100 — best fitness -7287.64332
#     iter 30/100 — best fitness -150294.40055
#     iter 40/100 — best fitness -5096149.28975
#     iter 50/100 — best fitness -26776719.43307
#     iter 60/100 — best fitness -33699685.62345
#     iter 70/100 — best fitness -237826961.61916
#     iter 80/100 — best fitness -391228933.49376
#     iter 90/100 — best fitness -2333659850.59567
#     iter 100/100 — best fitness -4954159878.34235
#   sample 31/50 (global 30)
#     iter 1/100 — best fitness 971.71625
#     iter 10/100 — best fitness 971.71625
#     iter 20/100 — best fitness 964.67877
#     iter 30/100 — best fitness 961.92175
#     iter 40/100 — best fitness 945.32990
#     iter 50/100 — best fitness 944.19666
#     iter 60/100 — best fitness 944.19666
#     iter 70/100 — best fitness 941.76105
#     iter 80/100 — best fitness 935.15070
#     iter 90/100 — best fitness 930.76752
#     iter 100/100 — best fitness 930.25909
#   sample 32/50 (global 31)
#     iter 1/100 — best fitness 941.67871
#     iter 10/100 — best fitness 939.59052
#     iter 20/100 — best fitness 939.59052
#     iter 30/100 — best fitness 939.59052
#     iter 40/100 — best fitness 939.59052
#     iter 50/100 — best fitness 939.59052
#     iter 60/100 — best fitness 939.59052
#     iter 70/100 — best fitness 939.59052
#     iter 80/100 — best fitness 938.83093
#     iter 90/100 — best fitness 937.26093
#     iter 100/100 — best fitness 932.86261
#   sample 33/50 (global 32)
#     iter 1/100 — best fitness -119.01030
#     iter 10/100 — best fitness -6060.60100
#     iter 20/100 — best fitness -240861.35109
#     iter 30/100 — best fitness -352909.60938
#     iter 40/100 — best fitness -4711274.36243
#     iter 50/100 — best fitness -17657215.35945
#     iter 60/100 — best fitness -45107068.70817
#     iter 70/100 — best fitness -95534307.74613
#     iter 80/100 — best fitness -160940598.28575
#     iter 90/100 — best fitness -443347196.42005
#     iter 100/100 — best fitness -564137645.76665
#   sample 34/50 (global 33)
#     iter 1/100 — best fitness -62157.87523
#     iter 10/100 — best fitness -4313390.60337
#     iter 20/100 — best fitness -22298301.71614
#     iter 30/100 — best fitness -106088262.04263
#     iter 40/100 — best fitness -369755340.33612
#     iter 50/100 — best fitness -1504761610.68097
#     iter 60/100 — best fitness -5228136203.49591
#     iter 70/100 — best fitness -7373147031.56763
#     iter 80/100 — best fitness -13532456189.63647
#     iter 90/100 — best fitness -21580082197.44434
#     iter 100/100 — best fitness -24869991558.25232
#   sample 35/50 (global 34)
#     iter 1/100 — best fitness 964.61725
#     iter 10/100 — best fitness 964.61725
#     iter 20/100 — best fitness 961.88049
#     iter 30/100 — best fitness 948.11816
#     iter 40/100 — best fitness 948.11816
#     iter 50/100 — best fitness 941.71606
#     iter 60/100 — best fitness 941.71606
#     iter 70/100 — best fitness 941.71606
#     iter 80/100 — best fitness 936.56012
#     iter 90/100 — best fitness 932.73560
#     iter 100/100 — best fitness 932.73560
#   sample 36/50 (global 35)
#     iter 1/100 — best fitness 956.01465
#     iter 10/100 — best fitness 956.01465
#     iter 20/100 — best fitness 956.01465
#     iter 30/100 — best fitness 956.01465
#     iter 40/100 — best fitness 953.41657
#     iter 50/100 — best fitness 942.81726
#     iter 60/100 — best fitness 935.54871
#     iter 70/100 — best fitness 935.54871
#     iter 80/100 — best fitness 935.54871
#     iter 90/100 — best fitness 934.67261
#     iter 100/100 — best fitness 933.05518
#   sample 37/50 (global 36)
#     iter 1/100 — best fitness -28742.53320
#     iter 10/100 — best fitness -8460388.95667
#     iter 20/100 — best fitness -426462002.06380
#     iter 30/100 — best fitness -1058019528.78962
#     iter 40/100 — best fitness -4307905795.89713
#     iter 50/100 — best fitness -49578007503.24597
#     iter 60/100 — best fitness -56880544459.71741
#     iter 70/100 — best fitness -69122732911.62683
#     iter 80/100 — best fitness -75246976648.86719
#     iter 90/100 — best fitness -83070620330.57031
#     iter 100/100 — best fitness -95820015703.20129
#   sample 38/50 (global 37)
#     iter 1/100 — best fitness -116983.96497
#     iter 10/100 — best fitness -230906549.42987
#     iter 20/100 — best fitness -1692555026.46301
#     iter 30/100 — best fitness -47216904.96834
#     iter 40/100 — best fitness -444544587.95950
#     iter 50/100 — best fitness -2839893762.44086
#     iter 60/100 — best fitness -15131508186.94922
#     iter 70/100 — best fitness -34612122832.03906
#     iter 80/100 — best fitness -38218897627.93835
#     iter 90/100 — best fitness -46166318694.32080
#     iter 100/100 — best fitness -58247989457.17969
#   sample 45/50 (global 44)
#     iter 1/100 — best fitness 962.94049
#     iter 10/100 — best fitness 962.94049
#     iter 20/100 — best fitness 953.11713
#     iter 30/100 — best fitness 944.21442
#     iter 40/100 — best fitness 942.86798
#     iter 50/100 — best fitness 942.41846
#     iter 60/100 — best fitness 930.48047
#     iter 70/100 — best fitness 929.82501
#     iter 80/100 — best fitness 929.74573
#     iter 90/100 — best fitness 929.33130
#     iter 100/100 — best fitness 927.36853
#   sample 46/50 (global 45)
#     iter 1/100 — best fitness 960.18677
#     iter 10/100 — best fitness 960.18677
#     iter 20/100 — best fitness 949.01514
#     iter 30/100 — best fitness 939.99908
#     iter 40/100 — best fitness 936.57483
#     iter 50/100 — best fitness 936.57483
#     iter 60/100 — best fitness 930.47369
#     iter 70/100 — best fitness 930.32733
#     iter 80/100 — best fitness 929.81885
#     iter 90/100 — best fitness 925.62976
#     iter 100/100 — best fitness 921.19592
#   sample 47/50 (global 46)
#     iter 1/100 — best fitness 962.08887
#     iter 10/100 — best fitness 962.08887
#     iter 20/100 — best fitness 962.08887
#     iter 30/100 — best fitness 941.02734
#     iter 40/100 — best fitness 941.02734
#     iter 50/100 — best fitness 938.87659
#     iter 60/100 — best fitness 936.48248
#     iter 70/100 — best fitness 934.16779
#     iter 80/100 — best fitness 933.64520
#     iter 90/100 — best fitness 932.49445
#     iter 100/100 — best fitness 924.97553
#   sample 48/50 (global 47)
#     iter 1/100 — best fitness 951.90820
#     iter 10/100 — best fitness 951.90820
#     iter 20/100 — best fitness 951.68427
#     iter 30/100 — best fitness 951.68427
#     iter 40/100 — best fitness 949.44995
#     iter 50/100 — best fitness 930.46997
#     iter 60/100 — best fitness 929.68390
#     iter 70/100 — best fitness 929.68390
#     iter 80/100 — best fitness 929.64764
#     iter 90/100 — best fitness 929.41357
#     iter 100/100 — best fitness 928.76697
#   sample 49/50 (global 48)
#     iter 1/100 — best fitness 948.34070
#     iter 10/100 — best fitness 948.34070
#     iter 20/100 — best fitness 948.34070
#     iter 30/100 — best fitness 946.21845
#     iter 40/100 — best fitness 938.85657
#     iter 50/100 — best fitness 938.69360
#     iter 60/100 — best fitness 938.69360
#     iter 70/100 — best fitness 938.62177
#     iter 80/100 — best fitness 935.75897
#     iter 90/100 — best fitness 932.26660
#     iter 100/100 — best fitness 931.57666
#   sample 50/50 (global 49)
#     iter 1/100 — best fitness -70835312779.79169
#     iter 10/100 — best fitness -95460795281.49316
#     iter 20/100 — best fitness -126764983030.52380
#     iter 30/100 — best fitness -143763398032.90735
#     iter 40/100 — best fitness -153093708854.77893
#     iter 50/100 — best fitness -168543051536.86060
#     iter 60/100 — best fitness -175852755346.03857
#     iter 70/100 — best fitness -193358897018.83984
#     iter 80/100 — best fitness -215716284556.22156
#     iter 90/100 — best fitness -228399065778.59106
#     iter 100/100 — best fitness -230681875985.22656
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/100 — best fitness -142030.78392
#     iter 10/100 — best fitness -171839454.38461
#     iter 20/100 — best fitness -10519534473.80432
#     iter 30/100 — best fitness -39015234793.81470
#     iter 40/100 — best fitness -58770107106.15613
#     iter 50/100 — best fitness -68367370437.14929
#     iter 60/100 — best fitness -84589203688.09521
#     iter 70/100 — best fitness -104217346935.54797
#     iter 80/100 — best fitness -117837303910.82532
#     iter 90/100 — best fitness -129387320315.93665
#     iter 100/100 — best fitness -132406119141.16101
#   sample 2/50 (global 51)
#     iter 1/100 — best fitness 964.82074
#     iter 10/100 — best fitness -380405.31096
#     iter 20/100 — best fitness -1826220.00359
#     iter 30/100 — best fitness -104241056.00849
#     iter 40/100 — best fitness -369633618.43183
#     iter 50/100 — best fitness -1114994910.39611
#     iter 60/100 — best fitness -14530433504.26367
#     iter 70/100 — best fitness -23553389396.70496
#     iter 80/100 — best fitness -25782395679.19226
#     iter 90/100 — best fitness -42890461755.19043
#     iter 100/100 — best fitness -53324235752.33765
#   sample 3/50 (global 52)
#     iter 1/100 — best fitness 945.50647
#     iter 10/100 — best fitness -81210.88236
#     iter 20/100 — best fitness -1036004.48922
#     iter 30/100 — best fitness -27555472.47634
#     iter 40/100 — best fitness -86112204.32659
#     iter 50/100 — best fitness -357403685.92418
#     iter 60/100 — best fitness -4368182496.54980
#     iter 70/100 — best fitness -12190753279.40039
#     iter 80/100 — best fitness -17285244514.37036
#     iter 90/100 — best fitness -27756825730.30884
#     iter 100/100 — best fitness -33104511546.36414
#   sample 4/50 (global 53)
#     iter 1/100 — best fitness -378071.28496
#     iter 10/100 — best fitness -48875539.81525
#     iter 20/100 — best fitness -4800631509.91962
#     iter 30/100 — best fitness -27910498471.97900
#     iter 40/100 — best fitness -57059582540.87927
#     iter 50/100 — best fitness -66219195189.97375
#     iter 60/100 — best fitness -83577641301.29968
#     iter 70/100 — best fitness -119456499857.67407
#     iter 80/100 — best fitness -132803973005.38245
#     iter 90/100 — best fitness -143081444544.47449
#     iter 100/100 — best fitness -167386397155.39648
#   sample 5/50 (global 54)
#     iter 1/100 — best fitness -2852411.78980
#     iter 10/100 — best fitness -45747960.80474
#     iter 20/100 — best fitness -1617032414.06775
#     iter 30/100 — best fitness -21064924079.53076
#     iter 40/100 — best fitness -61266397304.74182
#     iter 50/100 — best fitness -86424244697.43274
#     iter 60/100 — best fitness -95462635799.93152
#     iter 70/100 — best fitness -115819052510.27625
#     iter 80/100 — best fitness -127453755163.37244
#     iter 90/100 — best fitness -140041712538.01392
#     iter 100/100 — best fitness -146085442362.73328
#   sample 6/50 (global 55)
#     iter 1/100 — best fitness -32284974050.99518
#     iter 10/100 — best fitness -87208165030.59326
#     iter 20/100 — best fitness -111133135622.35095
#     iter 30/100 — best fitness -137634848385.29724
#     iter 60/100 — best fitness -142233256126.67432
#     iter 70/100 — best fitness -169499796679.02344
#     iter 80/100 — best fitness -181716097641.89526
#     iter 90/100 — best fitness -202452200681.61658
#     iter 100/100 — best fitness -213828734188.36816
#   sample 36/50 (global 85)
#     iter 1/100 — best fitness -159.87749
#     iter 10/100 — best fitness -21206446.06673
#     iter 20/100 — best fitness -438211911.27346
#     iter 30/100 — best fitness -1437703933.02959
#     iter 40/100 — best fitness -2600544792.70007
#     iter 50/100 — best fitness -5079317191.43994
#     iter 60/100 — best fitness -10009548747.17126
#     iter 70/100 — best fitness -25446018055.04858
#     iter 80/100 — best fitness -46118673158.50793
#     iter 90/100 — best fitness -56479209733.46826
#     iter 100/100 — best fitness -65936511825.69116
#   sample 37/50 (global 86)
#     iter 1/100 — best fitness -306540.25000
#     iter 10/100 — best fitness -1586695.13496
#     iter 20/100 — best fitness -6047456347.69067
#     iter 30/100 — best fitness -6741668066.04504
#     iter 40/100 — best fitness -21221829710.35229
#     iter 50/100 — best fitness -50685843282.14685
#     iter 60/100 — best fitness -57542461211.23401
#     iter 70/100 — best fitness -67289999771.49731
#     iter 80/100 — best fitness -102121533188.94678
#     iter 90/100 — best fitness -109327448636.18250
#     iter 100/100 — best fitness -117387455731.08191
#   sample 38/50 (global 87)
#     iter 1/100 — best fitness -362525.08860
#     iter 10/100 — best fitness -23496026.70913
#     iter 20/100 — best fitness -1648345519.42436
#     iter 30/100 — best fitness -6351464445.98468
#     iter 40/100 — best fitness -17639192380.74451
#     iter 50/100 — best fitness -18095401557.94836
#     iter 60/100 — best fitness -45799082537.85193
#     iter 70/100 — best fitness -54385780113.01868
#     iter 80/100 — best fitness -68212436459.49304
#     iter 90/100 — best fitness -89821528212.11987
#     iter 100/100 — best fitness -114233559382.83521
#   sample 39/50 (global 88)
#     iter 1/100 — best fitness -2079203449.33406
#     iter 10/100 — best fitness -7618095997.03406
#     iter 20/100 — best fitness -23703171106.46997
#     iter 30/100 — best fitness -53831771709.99292
#     iter 40/100 — best fitness -76045631254.59814
#     iter 50/100 — best fitness -95957602295.51929
# ...
#     iter 20/100 — best fitness -375280836.59314
#     iter 30/100 — best fitness -9638676726.28601
#     iter 40/100 — best fitness -28968740776.87463
#     iter 50/100 — best fitness -50661310005.99976
#     iter 60/100 — best fitness -75399230778.69324
#     iter 70/100 — best fitness -93749874890.57227
#     iter 80/100 — best fitness -112880410018.22986
#     iter 90/100 — best fitness -132694338615.51685
#     iter 100/100 — best fitness -146524409110.49512
#   sample 26/50 (global 475)
#     iter 1/100 — best fitness -2280558592.00000
#     iter 10/100 — best fitness -21888803361.43945
#     iter 20/100 — best fitness -96184100001.27271
#     iter 30/100 — best fitness -125905016780.15295
#     iter 40/100 — best fitness -155166329167.67175
#     iter 50/100 — best fitness -198437880331.72681
#     iter 60/100 — best fitness -213360136794.35083
#     iter 70/100 — best fitness -235452498249.15027
#     iter 80/100 — best fitness -236515005880.31152
#     iter 90/100 — best fitness -263311575695.41724
#     iter 100/100 — best fitness -281256045134.89343
#     iter 40/100 — best fitness -206591013738.83313
#     iter 50/100 — best fitness -228143767176.77991
#     iter 60/100 — best fitness -245787905501.32935
#     iter 70/100 — best fitness -277592180995.51184
#     iter 80/100 — best fitness -310099085594.12891
#     iter 90/100 — best fitness -321347197312.94348
#     iter 100/100 — best fitness -333748282208.32031
#   sample 45/50 (global 494)
#     iter 1/100 — best fitness -9875815085.05731
#     iter 10/100 — best fitness -67427681828.84216
#     iter 20/100 — best fitness -169684313618.30115
#     iter 30/100 — best fitness -239494952020.34631
#     iter 40/100 — best fitness -273342608255.66626
#     iter 50/100 — best fitness -285561369698.17188
#     iter 60/100 — best fitness -321383284361.50464
#     iter 70/100 — best fitness -330940932059.41492
#     iter 80/100 — best fitness -381956137470.98364
#     iter 90/100 — best fitness -386612318804.36011
#     iter 100/100 — best fitness -398059920114.75403
#   sample 46/50 (global 495)
#     iter 1/100 — best fitness -6586719.09721
#     iter 10/100 — best fitness -2151841532.22502
#     iter 20/100 — best fitness -64875367961.12317
#     iter 30/100 — best fitness -93637131532.29895
#     iter 40/100 — best fitness -108562077330.79468
#     iter 50/100 — best fitness -145409172815.72778
#     iter 60/100 — best fitness -154661759170.74536
#     iter 70/100 — best fitness -167040480414.88831
#     iter 80/100 — best fitness -178046072757.96423
#     iter 90/100 — best fitness -197548064025.06360
#     iter 100/100 — best fitness -205144232545.24927
#   sample 47/50 (global 496)
#     iter 1/100 — best fitness -83650950342.16431
#     iter 10/100 — best fitness -157391804634.84375
#     iter 20/100 — best fitness -206876067013.38989
#     iter 30/100 — best fitness -217289313107.47998
#     iter 40/100 — best fitness -242424963741.29041
#     iter 50/100 — best fitness -268259943752.36060
#     iter 60/100 — best fitness -285632971558.47534
#     iter 70/100 — best fitness -289343088892.95801
#     iter 80/100 — best fitness -300967081828.39307
#     iter 90/100 — best fitness -319717825693.60254
#     iter 100/100 — best fitness -347131460951.39819
#   sample 48/50 (global 497)
#     iter 1/100 — best fitness -2565.40063
#     iter 10/100 — best fitness -7748097.97432
#     iter 20/100 — best fitness -11723428.78258
#     iter 30/100 — best fitness -1657739806.10362
#     iter 40/100 — best fitness -13122068694.66296
#     iter 50/100 — best fitness -34312034883.34314
#     iter 60/100 — best fitness -56261261723.54236
#     iter 70/100 — best fitness -73376258624.54431
#     iter 80/100 — best fitness -81600493190.42810
#     iter 90/100 — best fitness -96876906220.99255
#     iter 100/100 — best fitness -101093605748.74536
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -85584117760.00000
#     iter 10/100 — best fitness -120926741494.78821
#     iter 20/100 — best fitness -182322100503.24829
#     iter 30/100 — best fitness -217796744199.30176
#     iter 40/100 — best fitness -231841582141.59448
#     iter 50/100 — best fitness -250673140358.38074
#     iter 60/100 — best fitness -279070128257.97168
#     iter 70/100 — best fitness -307696455760.84778
#     iter 80/100 — best fitness -343280676639.95801
#     iter 90/100 — best fitness -362772444513.86060
#     iter 100/100 — best fitness -377622526906.88049
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -24412987.99672
#     iter 10/100 — best fitness -2197580037.54378
#     iter 20/100 — best fitness -52968934875.40588
#     iter 30/100 — best fitness -89795378468.52722
#     iter 40/100 — best fitness -115966633562.19250
#     iter 50/100 — best fitness -127788037134.60889
#     iter 60/100 — best fitness -167108458329.20410
#     iter 70/100 — best fitness -182462252361.49695
#     iter 80/100 — best fitness -200929945687.56238
#     iter 90/100 — best fitness -209397047794.14307
#     iter 100/100 — best fitness -214727858332.98279
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 292
# Detailed results  CSV    : Generated Data/C-CSA_images\c_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/C-CSA_images\c_csa_stats_per_digit.csv
# Total time               : 8172.48 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   30             20     50       60.0      40.0
# 1                    3             47     50        6.0      94.0
# 2                   36             14     50       72.0      28.0
# 3                   30             20     50       60.0      40.0
# 4                   11             39     50       22.0      78.0
# 5                   32             18     50       64.0      36.0
# 6                   25             25     50       50.0      50.0
# 7                   30             20     50       60.0      40.0
# 8                    8             42     50       16.0      84.0
# 9                    3             47     50        6.0      94.0

# %% [markdown]
# #### Z-CSA

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = False           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "MainModel_MLP1L.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e9,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _levy_flight(self) -> torch.Tensor:
        # Lévy flight (Mantegna’s algorithm, β = 1.5)
        import math
        beta  = 1.5
        sigma = (math.gamma(1 + beta) * math.sin(np.pi * beta / 2) /
                 (math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u     = torch.randn(self.dim, device=device) * (sigma * self.step_size)
        v     = torch.randn(self.dim, device=device)
        step  = u / torch.pow(torch.abs(v), 1 / beta)
        return step


    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._levy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "MLP1L_500_samples_train.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/Z-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "z_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "z_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\MainModel_MLP1L.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample

#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -32381.90435
#     iter 20/100 — best fitness -74051.74210
#     iter 30/100 — best fitness -167056.58168
#     iter 40/100 — best fitness -331560.85504
#     iter 50/100 — best fitness -549700.78202
#     iter 60/100 — best fitness -1028881.05092
#     iter 70/100 — best fitness -2083717.68827
#     iter 80/100 — best fitness -3551951.53430
#     iter 90/100 — best fitness -7352662.75581
#     iter 100/100 — best fitness -8998787.09556
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -15395.36494
#     iter 10/100 — best fitness -113667229616.58093
#     iter 20/100 — best fitness -138651436757.05847
#     iter 30/100 — best fitness -156366795482.82233
#     iter 40/100 — best fitness -163923281611.67242
#     iter 50/100 — best fitness -172801016708.89978
#     iter 60/100 — best fitness -182030867478.65649
#     iter 70/100 — best fitness -190662344831.65259
#     iter 80/100 — best fitness -196405085459.45642
#     iter 90/100 — best fitness -200228041545.10608
#     iter 100/100 — best fitness -203578280343.64233
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -3315948093.58347
#     iter 20/100 — best fitness -9615112681.84241
#     iter 30/100 — best fitness -13410822294.23584
#     iter 40/100 — best fitness -26078430590.46826
#     iter 50/100 — best fitness -32538920814.90607
#     iter 60/100 — best fitness -34370101864.95923
#     iter 70/100 — best fitness -37224320346.74811
#     iter 80/100 — best fitness -40007051402.07782
#     iter 90/100 — best fitness -48009289673.58929
#     iter 100/100 — best fitness -48604835444.36926
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 160
# Detailed results  CSV    : Generated Data/Z-CSA_images\z_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/Z-CSA_images\z_csa_stats_per_digit.csv
# Total time               : 6163.73 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   40             10     50       80.0      20.0
# 1                   24             26     50       48.0      52.0
# 2                   49              1     50       98.0       2.0
# 3                   38             12     50       76.0      24.0
# 4                   23             27     50       46.0      54.0
# 5                   41              9     50       82.0      18.0
# 6                   40             10     50       80.0      20.0
# 7                   38             12     50       76.0      24.0
# 8                   27             23     50       54.0      46.0
# 9                   20             30     50       40.0      60.0

# %% [markdown]
# #### CSA

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = False           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "MainModel_MLP1L.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e9,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.empty((n_nests, dim), dtype=torch.float32, device=device) \
                 .uniform_(float(self.raw_lower), float(self.raw_upper))

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _levy_flight(self) -> torch.Tensor:
        # Lévy flight (Mantegna’s algorithm, β = 1.5)
        import math
        beta  = 1.5
        sigma = (math.gamma(1 + beta) * math.sin(np.pi * beta / 2) /
                 (math.gamma((1 + beta) / 2) * beta * 2 ** ((beta - 1) / 2))) ** (1 / beta)
        u     = torch.randn(self.dim, device=device) * (sigma * self.step_size)
        v     = torch.randn(self.dim, device=device)
        step  = u / torch.pow(torch.abs(v), 1 / beta)
        return step


    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._levy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "MLP1L_500_samples_train.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\MainModel_MLP1L.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness 951.23340
#     iter 10/100 — best fitness 948.35675
#     iter 20/100 — best fitness 946.62201
#     iter 30/100 — best fitness 940.98108
#     iter 40/100 — best fitness 936.56677
#     iter 50/100 — best fitness 930.63208
#     iter 60/100 — best fitness 929.62927
#     iter 70/100 — best fitness 924.09027
#     iter 80/100 — best fitness 920.62000
#     iter 90/100 — best fitness 920.06964
#     iter 100/100 — best fitness 918.00397
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -75287.91406
#     iter 10/100 — best fitness -739243.03796
#     iter 20/100 — best fitness -43478906.24034
#     iter 30/100 — best fitness -48952667.57620
#     iter 40/100 — best fitness -86723294.04433
#     iter 50/100 — best fitness -254646652.72703
#     iter 60/100 — best fitness -290143285.23476
#     iter 70/100 — best fitness -550874448.19252
#     iter 80/100 — best fitness -802578566.33680
#     iter 90/100 — best fitness -872711253.12611
#     iter 100/100 — best fitness -1124809916.99943
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness 951.03796
#     iter 10/100 — best fitness 925.75501
#     iter 20/100 — best fitness 924.23322
#     iter 30/100 — best fitness 917.51111
#     iter 40/100 — best fitness 913.58704
#     iter 50/100 — best fitness 910.61926
#     iter 60/100 — best fitness 907.08185
#     iter 70/100 — best fitness 905.37061
#     iter 80/100 — best fitness 901.83655
#     iter 90/100 — best fitness 897.66644
#     iter 100/100 — best fitness 896.63007
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -1224393.00000
#     iter 10/100 — best fitness -3814161.08287
#     iter 20/100 — best fitness -9791979.29995
#     iter 30/100 — best fitness -11036417.88626
#     iter 40/100 — best fitness -28538618.19475
#     iter 50/100 — best fitness -38566207.41977
#     iter 60/100 — best fitness -65037388.55635
#     iter 70/100 — best fitness -84938589.35538
#     iter 80/100 — best fitness -98168354.61130
#     iter 90/100 — best fitness -117271007.02700
#     iter 100/100 — best fitness -142573689.94808
#   sample 5/50 (global 4)
#     iter 1/100 — best fitness 946.93933
#     iter 10/100 — best fitness 933.66150
#     iter 20/100 — best fitness 932.98090
#     iter 30/100 — best fitness 929.70453
#     iter 40/100 — best fitness 926.12097
#     iter 50/100 — best fitness 923.25531
#     iter 60/100 — best fitness 919.80896
#     iter 70/100 — best fitness 916.31287
#     iter 80/100 — best fitness 914.21985
#     iter 90/100 — best fitness 911.92108
#     iter 100/100 — best fitness 910.76715
#   sample 6/50 (global 5)
#     iter 1/100 — best fitness 951.64935
#     iter 10/100 — best fitness 950.52350
#     iter 20/100 — best fitness 946.68390
#     iter 30/100 — best fitness 944.20325
#     iter 40/100 — best fitness 940.70813
#     iter 50/100 — best fitness 933.82062
#     iter 60/100 — best fitness 931.75537
#     iter 70/100 — best fitness 930.27094
#     iter 80/100 — best fitness 927.84680
#     iter 90/100 — best fitness 924.86731
#     iter 100/100 — best fitness 923.40137
#   sample 7/50 (global 6)
#     iter 1/100 — best fitness 971.93719
#     iter 10/100 — best fitness 932.61224
#     iter 20/100 — best fitness 931.50439
#     iter 30/100 — best fitness 927.30792
#     iter 40/100 — best fitness 926.21545
#     iter 50/100 — best fitness 924.07184
#     iter 60/100 — best fitness 922.17590
#     iter 70/100 — best fitness 921.41205
#     iter 80/100 — best fitness 918.28381
#     iter 90/100 — best fitness 916.86597
#     iter 100/100 — best fitness 915.40924
#   sample 8/50 (global 7)
#     iter 1/100 — best fitness -950210.37500
#     iter 10/100 — best fitness -114830668.45317
#     iter 20/100 — best fitness -144108403.07321
#     iter 30/100 — best fitness -1489628411.13705
#     iter 40/100 — best fitness -2472609880.00151
#     iter 50/100 — best fitness -5099917797.10376
#     iter 60/100 — best fitness -9479810740.91425
#     iter 70/100 — best fitness -15058418654.52576
#     iter 80/100 — best fitness -21044427300.54395
#     iter 90/100 — best fitness -24728597546.16418
#     iter 100/100 — best fitness -25308579351.67676
#   sample 9/50 (global 8)
#     iter 1/100 — best fitness -27417589636.71649
#     iter 10/100 — best fitness -38155619083.35687
#     iter 20/100 — best fitness -58449691755.14075
#     iter 30/100 — best fitness -65776404359.35535
#     iter 40/100 — best fitness -74323796247.44696
#     iter 50/100 — best fitness -78921951209.99170
#     iter 60/100 — best fitness -87361659018.32465
#     iter 70/100 — best fitness -93612631706.47522
#     iter 80/100 — best fitness -99596194174.32935
#     iter 90/100 — best fitness -102731780017.67700
#     iter 100/100 — best fitness -104403370763.00610
#   sample 10/50 (global 9)
#     iter 1/100 — best fitness 955.12384
#     iter 10/100 — best fitness 949.79767
#     iter 20/100 — best fitness 943.29370
#     iter 30/100 — best fitness 937.67188
#     iter 40/100 — best fitness 936.75287
#     iter 50/100 — best fitness 934.15546
#     iter 60/100 — best fitness 931.15875
#     iter 70/100 — best fitness 927.76172
#     iter 80/100 — best fitness 925.13232
#     iter 90/100 — best fitness 923.21265
#     iter 100/100 — best fitness 920.10217
#   sample 11/50 (global 10)
#     iter 1/100 — best fitness 965.81982
#     iter 10/100 — best fitness 958.11963
#     iter 20/100 — best fitness 945.67450
#     iter 30/100 — best fitness 943.73950
#     iter 40/100 — best fitness 932.26172
#     iter 50/100 — best fitness 931.61371
#     iter 60/100 — best fitness 929.15210
#     iter 70/100 — best fitness 925.46057
#     iter 80/100 — best fitness 923.57709
#     iter 90/100 — best fitness 921.36633
#     iter 100/100 — best fitness 920.52374
#   sample 12/50 (global 11)
#     iter 1/100 — best fitness -282626176.00000
#     iter 10/100 — best fitness -1962250204.25990
#     iter 20/100 — best fitness -24524771140.33350
#     iter 30/100 — best fitness -44029344477.55920
#     iter 40/100 — best fitness -46601790346.03284
#     iter 50/100 — best fitness -51617731016.75525
#     iter 60/100 — best fitness -57802704726.30579
#     iter 70/100 — best fitness -59007967863.57532
#     iter 80/100 — best fitness -59099348935.64343
#     iter 90/100 — best fitness -63050722033.12024
#     iter 100/100 — best fitness -65680083184.45093
#   sample 13/50 (global 12)
#     iter 1/100 — best fitness 968.58502
#     iter 10/100 — best fitness 940.57282
#     iter 20/100 — best fitness 938.73138
#     iter 30/100 — best fitness 930.75708
#     iter 40/100 — best fitness 927.18884
#     iter 50/100 — best fitness 924.41095
#     iter 60/100 — best fitness 921.67603
#     iter 70/100 — best fitness 918.79016
#     iter 80/100 — best fitness 914.75317
#     iter 90/100 — best fitness 911.85968
#     iter 100/100 — best fitness 910.34375
#   sample 14/50 (global 13)
#     iter 1/100 — best fitness -1722310528.00000
#     iter 10/100 — best fitness -10016391463.54596
#     iter 20/100 — best fitness -20806971974.46912
#     iter 30/100 — best fitness -35994914930.33862
#     iter 40/100 — best fitness -44906424435.50232
#     iter 50/100 — best fitness -55291193879.77576
#     iter 60/100 — best fitness -60981701764.70789
#     iter 70/100 — best fitness -63099788579.73816
#     iter 80/100 — best fitness -66025537405.41760
#     iter 90/100 — best fitness -68965386304.49854
#     iter 100/100 — best fitness -69676207456.13464
#   sample 15/50 (global 14)
#     iter 1/100 — best fitness 941.35522
#     iter 10/100 — best fitness 940.89154
#     iter 20/100 — best fitness 937.66876
#     iter 30/100 — best fitness 932.67352
#     iter 40/100 — best fitness 926.26733
#     iter 50/100 — best fitness 925.91449
#     iter 60/100 — best fitness 922.80695
#     iter 70/100 — best fitness 920.44800
#     iter 80/100 — best fitness 918.42255
#     iter 90/100 — best fitness 917.38336
#     iter 100/100 — best fitness 916.50812
#   sample 16/50 (global 15)
#     iter 1/100 — best fitness -507506208.00000
#     iter 10/100 — best fitness -713184140.72089
#     iter 20/100 — best fitness -1209793020.64945
#     iter 30/100 — best fitness -3235113172.86700
#     iter 40/100 — best fitness -6633317591.91406
#     iter 50/100 — best fitness -13368882056.60120
#     iter 60/100 — best fitness -18371509427.80481
#     iter 70/100 — best fitness -23081547133.15979
#     iter 80/100 — best fitness -25492171159.15015
#     iter 90/100 — best fitness -27318621983.41467
#     iter 100/100 — best fitness -30451034416.96228
#   sample 17/50 (global 16)
#     iter 1/100 — best fitness 961.65509
#     iter 10/100 — best fitness 950.02106
#     iter 20/100 — best fitness 944.64801
#     iter 30/100 — best fitness 937.95087
#     iter 40/100 — best fitness 931.97070
#     iter 50/100 — best fitness 929.45862
#     iter 60/100 — best fitness 925.42249
#     iter 70/100 — best fitness 922.95270
#     iter 80/100 — best fitness 918.95740
#     iter 90/100 — best fitness 917.01068
#     iter 100/100 — best fitness 916.34454
#   sample 18/50 (global 17)
#     iter 1/100 — best fitness 956.39532
#     iter 10/100 — best fitness 952.71381
#     iter 20/100 — best fitness 947.46960
#     iter 30/100 — best fitness 941.94251
#     iter 40/100 — best fitness 932.99030
#     iter 50/100 — best fitness 931.33228
#     iter 60/100 — best fitness 930.52875
#     iter 70/100 — best fitness 927.07880
#     iter 80/100 — best fitness 925.52960
#     iter 90/100 — best fitness 922.26495
#     iter 100/100 — best fitness 919.55798
#   sample 19/50 (global 18)
#     iter 1/100 — best fitness 945.61285
#     iter 10/100 — best fitness 936.98303
#     iter 20/100 — best fitness 936.98303
#     iter 30/100 — best fitness 934.89368
#     iter 40/100 — best fitness 930.39594
#     iter 50/100 — best fitness 929.82141
#     iter 60/100 — best fitness 926.85236
#     iter 70/100 — best fitness 925.96893
#     iter 80/100 — best fitness 922.27741
#     iter 90/100 — best fitness 919.38330
#     iter 100/100 — best fitness 917.34876
#   sample 20/50 (global 19)
#     iter 1/100 — best fitness 966.36133
#     iter 10/100 — best fitness 956.24554
#     iter 20/100 — best fitness 949.69293
#     iter 30/100 — best fitness 946.79108
#     iter 40/100 — best fitness 935.29987
#     iter 50/100 — best fitness 933.05072
#     iter 60/100 — best fitness 931.15094
#     iter 70/100 — best fitness 928.05383
#     iter 80/100 — best fitness 922.80371
#     iter 90/100 — best fitness 919.34485
#     iter 100/100 — best fitness 917.93921
#   sample 21/50 (global 20)
#     iter 1/100 — best fitness -45701740.33730
#     iter 10/100 — best fitness -20286733104.34692
#     iter 20/100 — best fitness -31122952880.82520
#     iter 30/100 — best fitness -36742514549.38519
#     iter 40/100 — best fitness -41488326968.38757
#     iter 50/100 — best fitness -55043934755.16681
#     iter 60/100 — best fitness -64295567445.34473
#     iter 70/100 — best fitness -68533910682.34454
#     iter 80/100 — best fitness -68839482238.88287
#     iter 90/100 — best fitness -76057056357.71338
#     iter 100/100 — best fitness -77154573372.29974
#   sample 22/50 (global 21)
#     iter 1/100 — best fitness -60903714816.00000
#     iter 10/100 — best fitness -81196354806.00952
#     iter 20/100 — best fitness -95121840446.98969
#     iter 30/100 — best fitness -106841258008.45673
#     iter 40/100 — best fitness -111033476790.71979
#     iter 50/100 — best fitness -116797684628.17761
#     iter 60/100 — best fitness -126113385107.82166
#     iter 70/100 — best fitness -135088995870.56543
#     iter 80/100 — best fitness -137878569539.18036
#     iter 90/100 — best fitness -142788714344.31659
#     iter 100/100 — best fitness -143463858539.48004
#   sample 23/50 (global 22)
#     iter 1/100 — best fitness 943.23834
#     iter 10/100 — best fitness 936.49133
#     iter 20/100 — best fitness 929.33453
#     iter 30/100 — best fitness 925.22839
#     iter 40/100 — best fitness 922.61127
#     iter 50/100 — best fitness 920.84607
#     iter 60/100 — best fitness 919.01038
#     iter 70/100 — best fitness 917.92902
#     iter 80/100 — best fitness 916.29364
#     iter 90/100 — best fitness 912.56097
#     iter 100/100 — best fitness 911.05023
#   sample 24/50 (global 23)
#     iter 1/100 — best fitness -14484.16113
#     iter 10/100 — best fitness -229071.49393
#     iter 20/100 — best fitness -609328.95967
#     iter 30/100 — best fitness -1288726.58604
#     iter 40/100 — best fitness -3367246.61852
#     iter 50/100 — best fitness -4912747.95768
#     iter 60/100 — best fitness -15150913.24264
#     iter 70/100 — best fitness -17033771.69162
#     iter 80/100 — best fitness -26931403.38576
#     iter 90/100 — best fitness -29463410.24245
#     iter 100/100 — best fitness -39118382.40410
#   sample 25/50 (global 24)
#     iter 1/100 — best fitness 948.95514
#     iter 10/100 — best fitness 931.34534
#     iter 20/100 — best fitness 930.91437
#     iter 30/100 — best fitness 926.13544
#     iter 40/100 — best fitness 923.34277
#     iter 50/100 — best fitness 921.58545
#     iter 60/100 — best fitness 918.86755
#     iter 70/100 — best fitness 917.95685
#     iter 80/100 — best fitness 914.70569
#     iter 90/100 — best fitness 912.83618
#     iter 100/100 — best fitness 909.86786
#   sample 26/50 (global 25)
#     iter 1/100 — best fitness 967.14410
#     iter 10/100 — best fitness 954.95850
#     iter 20/100 — best fitness 949.97803
#     iter 30/100 — best fitness 943.40021
#     iter 40/100 — best fitness 940.77820
#     iter 50/100 — best fitness 928.79004
#     iter 60/100 — best fitness 922.66217
#     iter 70/100 — best fitness 922.57367
#     iter 80/100 — best fitness 917.25671
#     iter 90/100 — best fitness 914.57397
#     iter 100/100 — best fitness 912.10095
#   sample 27/50 (global 26)
#     iter 1/100 — best fitness 963.85431
#     iter 10/100 — best fitness 938.45294
#     iter 20/100 — best fitness 937.57019
#     iter 30/100 — best fitness 931.49335
#     iter 40/100 — best fitness 931.09589
#     iter 50/100 — best fitness 927.69519
#     iter 60/100 — best fitness 925.38031
#     iter 70/100 — best fitness 921.41864
#     iter 80/100 — best fitness 915.85498
#     iter 90/100 — best fitness 913.13403
#     iter 100/100 — best fitness 909.93298
#   sample 28/50 (global 27)
#     iter 1/100 — best fitness 969.39563
#     iter 10/100 — best fitness 952.32233
#     iter 20/100 — best fitness 940.16846
#     iter 30/100 — best fitness 934.54932
#     iter 40/100 — best fitness 932.23383
#     iter 50/100 — best fitness 930.14630
#     iter 60/100 — best fitness 927.30487
#     iter 70/100 — best fitness 924.32532
#     iter 80/100 — best fitness 923.19519
#     iter 90/100 — best fitness 921.48639
#     iter 100/100 — best fitness 918.95160
#   sample 29/50 (global 28)
#     iter 1/100 — best fitness -11764877312.00000
#     iter 10/100 — best fitness -14908242389.74707
#     iter 20/100 — best fitness -37253223787.27405
#     iter 30/100 — best fitness -49623721961.04297
#     iter 40/100 — best fitness -57196630360.89661
#     iter 50/100 — best fitness -61379660492.66907
#     iter 60/100 — best fitness -69849413755.71008
#     iter 70/100 — best fitness -72798570513.75940
#     iter 80/100 — best fitness -76640642999.48975
#     iter 90/100 — best fitness -82010220407.85474
#     iter 100/100 — best fitness -83114518043.25427
#   sample 30/50 (global 29)
#     iter 1/100 — best fitness 950.28131
#     iter 10/100 — best fitness 950.28131
#     iter 20/100 — best fitness 940.65765
#     iter 30/100 — best fitness -222.49669
#     iter 40/100 — best fitness -223.48552
#     iter 50/100 — best fitness -224.82873
#     iter 60/100 — best fitness -227.06951
#     iter 70/100 — best fitness -227.95971
#     iter 80/100 — best fitness -232.20458
#     iter 90/100 — best fitness -233.94201
#     iter 100/100 — best fitness -235.53069
#   sample 31/50 (global 30)
#     iter 1/100 — best fitness 965.77228
#     iter 10/100 — best fitness 936.18909
#     iter 20/100 — best fitness 935.11939
#     iter 30/100 — best fitness 931.10004
#     iter 40/100 — best fitness 930.47650
#     iter 50/100 — best fitness 928.73926
#     iter 60/100 — best fitness 926.39136
#     iter 70/100 — best fitness 923.80908
#     iter 80/100 — best fitness 923.55994
#     iter 90/100 — best fitness 920.98438
#     iter 100/100 — best fitness 920.72424
#   sample 32/50 (global 31)
#     iter 1/100 — best fitness 946.21112
#     iter 10/100 — best fitness 940.78601
#     iter 20/100 — best fitness 938.90942
#     iter 30/100 — best fitness 934.11713
#     iter 40/100 — best fitness 932.40479
#     iter 50/100 — best fitness 928.86560
#     iter 60/100 — best fitness 927.72467
#     iter 70/100 — best fitness 925.63709
#     iter 80/100 — best fitness 923.31830
#     iter 90/100 — best fitness 921.45990
#     iter 100/100 — best fitness 918.08337
#   sample 33/50 (global 32)
#     iter 1/100 — best fitness -24022.31662
#     iter 10/100 — best fitness -63359.33562
#     iter 20/100 — best fitness -120575.34327
#     iter 30/100 — best fitness -292233.26547
#     iter 40/100 — best fitness -354216.69153
#     iter 50/100 — best fitness -602155.29717
#     iter 60/100 — best fitness -1336411.11217
#     iter 70/100 — best fitness -1863225.64173
#     iter 80/100 — best fitness -2892941.26363
#     iter 90/100 — best fitness -3897531.83446
#     iter 100/100 — best fitness -4381322.71581
#   sample 34/50 (global 33)
#     iter 1/100 — best fitness -14489.10664
#     iter 10/100 — best fitness -83601.06900
#     iter 20/100 — best fitness -786948.13711
#     iter 30/100 — best fitness -1452062.01442
#     iter 40/100 — best fitness -2011052.50376
#     iter 50/100 — best fitness -3480429.10120
#     iter 60/100 — best fitness -4672102.09777
#     iter 70/100 — best fitness -7876817.03170
#     iter 80/100 — best fitness -10695874.21101
#     iter 90/100 — best fitness -11516314.63717
#     iter 100/100 — best fitness -13783189.20267
#   sample 35/50 (global 34)
#     iter 1/100 — best fitness 959.87964
#     iter 10/100 — best fitness 949.98407
#     iter 20/100 — best fitness 935.42657
#     iter 30/100 — best fitness 933.24658
#     iter 40/100 — best fitness 928.75562
#     iter 50/100 — best fitness 928.75562
#     iter 60/100 — best fitness 925.43420
#     iter 70/100 — best fitness 920.86780
#     iter 80/100 — best fitness 918.87805
#     iter 90/100 — best fitness 917.49402
#     iter 100/100 — best fitness 916.55780
#   sample 36/50 (global 35)
#     iter 1/100 — best fitness 967.33844
#     iter 10/100 — best fitness 949.62402
#     iter 20/100 — best fitness 940.73706
#     iter 30/100 — best fitness 938.13074
#     iter 40/100 — best fitness 934.49316
#     iter 50/100 — best fitness 931.11224
#     iter 60/100 — best fitness 929.12616
#     iter 70/100 — best fitness 926.70679
#     iter 80/100 — best fitness 924.72034
#     iter 90/100 — best fitness 922.58173
#     iter 100/100 — best fitness 920.65961
#   sample 37/50 (global 36)
#     iter 1/100 — best fitness -15683.61874
#     iter 10/100 — best fitness -224298.86980
#     iter 20/100 — best fitness -847694.07166
#     iter 30/100 — best fitness -4241901.64860
#     iter 40/100 — best fitness -16779068.14669
#     iter 50/100 — best fitness -44638419.99132
#     iter 60/100 — best fitness -74410799.78195
#     iter 70/100 — best fitness -223189757.20079
#     iter 80/100 — best fitness -236234494.90758
#     iter 90/100 — best fitness -413092521.60193
#     iter 100/100 — best fitness -447947752.94619
#   sample 38/50 (global 37)
#     iter 1/100 — best fitness -1049159.20176
#     iter 10/100 — best fitness -2510393.54793
#     iter 20/100 — best fitness -7739797.49794
#     iter 30/100 — best fitness -31586017.73672
#     iter 40/100 — best fitness -86076809.87679
#     iter 50/100 — best fitness -236646647.88644
#     iter 60/100 — best fitness -480955246.68422
#     iter 70/100 — best fitness -695393234.14355
#     iter 80/100 — best fitness -1256477087.97452
#     iter 90/100 — best fitness -1481842995.36473
#     iter 100/100 — best fitness -1541229485.98546
#   sample 39/50 (global 38)
#     iter 1/100 — best fitness -8821864301.84912
#     iter 10/100 — best fitness -16097223912.14954
#     iter 20/100 — best fitness -25322014241.91992
#     iter 30/100 — best fitness -31508451857.59900
#     iter 40/100 — best fitness -36663724336.17676
#     iter 50/100 — best fitness -43397530465.12756
#     iter 60/100 — best fitness -46478728203.14441
#     iter 70/100 — best fitness -51152137667.48401
#     iter 80/100 — best fitness -60462964922.44434
#     iter 90/100 — best fitness -63077777772.05652
#     iter 100/100 — best fitness -65227335838.82690
#   sample 40/50 (global 39)
#     iter 1/100 — best fitness 963.99744
#     iter 10/100 — best fitness 948.54785
#     iter 20/100 — best fitness 947.65338
#     iter 30/100 — best fitness 942.34876
#     iter 40/100 — best fitness 939.98743
#     iter 50/100 — best fitness 935.02881
#     iter 60/100 — best fitness 931.64545
#     iter 70/100 — best fitness 927.87988
#     iter 80/100 — best fitness 926.39612
#     iter 90/100 — best fitness 923.56781
#     iter 100/100 — best fitness 921.47290
#   sample 41/50 (global 40)
#     iter 1/100 — best fitness -1506865.18578
#     iter 10/100 — best fitness -6265029.19100
#     iter 20/100 — best fitness -115220746.57854
#     iter 30/100 — best fitness -247195856.63661
#     iter 40/100 — best fitness -917543868.52288
#     iter 50/100 — best fitness -1117747898.28616
#     iter 60/100 — best fitness -1802861117.48473
#     iter 70/100 — best fitness -2809739578.57852
#     iter 80/100 — best fitness -3425231446.40140
#     iter 90/100 — best fitness -4918049744.01849
#     iter 100/100 — best fitness -5207809975.00104
#   sample 42/50 (global 41)
#     iter 1/100 — best fitness -63377.00000
#     iter 10/100 — best fitness -715405.79963
#     iter 20/100 — best fitness -5440607.37240
#     iter 30/100 — best fitness -21654914.93778
#     iter 40/100 — best fitness -66161316.77174
#     iter 50/100 — best fitness -153143870.75943
#     iter 60/100 — best fitness -351619805.15615
#     iter 70/100 — best fitness -963515507.89053
#     iter 80/100 — best fitness -1238982324.88801
#     iter 90/100 — best fitness -2044588646.10072
#     iter 100/100 — best fitness -5155937840.40302
#   sample 43/50 (global 42)
#     iter 1/100 — best fitness 965.54156
#     iter 10/100 — best fitness 948.98059
#     iter 20/100 — best fitness 935.22864
#     iter 30/100 — best fitness 931.17554
#     iter 40/100 — best fitness 929.85852
#     iter 50/100 — best fitness 924.35040
#     iter 60/100 — best fitness 921.14893
#     iter 70/100 — best fitness 919.83759
#     iter 80/100 — best fitness 919.09222
#     iter 90/100 — best fitness 917.79504
#     iter 100/100 — best fitness 915.37799
#   sample 44/50 (global 43)
#     iter 1/100 — best fitness 954.28857
#     iter 10/100 — best fitness -2573.17631
#     iter 20/100 — best fitness -9714.10577
#     iter 30/100 — best fitness -16856.71467
#     iter 40/100 — best fitness -51420.68621
#     iter 50/100 — best fitness -174200.94178
#     iter 60/100 — best fitness -256448.74999
#     iter 70/100 — best fitness -318436.08640
#     iter 80/100 — best fitness -571133.10712
#     iter 90/100 — best fitness -721338.18937
#     iter 100/100 — best fitness -894167.22258
#   sample 45/50 (global 44)
#     iter 1/100 — best fitness 953.00885
#     iter 10/100 — best fitness 952.67731
#     iter 20/100 — best fitness 948.93481
#     iter 30/100 — best fitness 945.92798
#     iter 40/100 — best fitness 944.18469
#     iter 50/100 — best fitness 934.33087
#     iter 60/100 — best fitness 930.48102
#     iter 70/100 — best fitness 929.81036
#     iter 80/100 — best fitness 928.51440
#     iter 90/100 — best fitness 926.91632
#     iter 100/100 — best fitness 924.83814
#   sample 46/50 (global 45)
#     iter 1/100 — best fitness 961.59424
#     iter 10/100 — best fitness 949.13367
#     iter 20/100 — best fitness 947.87604
#     iter 30/100 — best fitness 946.31989
#     iter 40/100 — best fitness 941.67169
#     iter 50/100 — best fitness 935.16803
#     iter 60/100 — best fitness 932.68707
#     iter 70/100 — best fitness 926.75342
#     iter 80/100 — best fitness 923.77789
#     iter 90/100 — best fitness 922.49731
#     iter 100/100 — best fitness 920.76581
#   sample 47/50 (global 46)
#     iter 1/100 — best fitness 956.90405
#     iter 10/100 — best fitness 951.15649
#     iter 20/100 — best fitness 947.75769
#     iter 30/100 — best fitness 942.09711
#     iter 40/100 — best fitness 936.98016
#     iter 50/100 — best fitness 932.84607
#     iter 60/100 — best fitness 931.14539
#     iter 70/100 — best fitness 930.63043
#     iter 80/100 — best fitness 929.05280
#     iter 90/100 — best fitness 926.77991
#     iter 100/100 — best fitness 925.29822
#   sample 48/50 (global 47)
#     iter 1/100 — best fitness 966.24200
#     iter 10/100 — best fitness 945.35571
#     iter 20/100 — best fitness 939.53784
#     iter 30/100 — best fitness 933.26630
#     iter 40/100 — best fitness 930.92957
#     iter 50/100 — best fitness 924.13477
#     iter 60/100 — best fitness 913.89557
#     iter 70/100 — best fitness 913.14539
#     iter 80/100 — best fitness 912.35529
#     iter 90/100 — best fitness 911.25165
#     iter 100/100 — best fitness 910.41840
#   sample 49/50 (global 48)
#     iter 1/100 — best fitness 955.03693
#     iter 10/100 — best fitness 950.41248
#     iter 20/100 — best fitness 944.04987
#     iter 30/100 — best fitness 936.83795
#     iter 40/100 — best fitness 933.61542
#     iter 50/100 — best fitness 929.51447
#     iter 60/100 — best fitness 925.58075
#     iter 70/100 — best fitness 923.11945
#     iter 80/100 — best fitness 921.94800
#     iter 90/100 — best fitness 920.30945
#     iter 100/100 — best fitness 918.40649
#   sample 50/50 (global 49)
#     iter 1/100 — best fitness -56343707019.23596
#     iter 10/100 — best fitness -88245505273.96381
#     iter 20/100 — best fitness -105028542452.97943
#     iter 30/100 — best fitness -108587836192.08411
#     iter 40/100 — best fitness -114093483852.07690
#     iter 50/100 — best fitness -120265416070.51477
#     iter 60/100 — best fitness -122748249929.99548
#     iter 70/100 — best fitness -125317467615.94141
#     iter 80/100 — best fitness -126753930009.02185
#     iter 90/100 — best fitness -131354473994.82605
#     iter 100/100 — best fitness -133417157100.22449
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/100 — best fitness -108669.85938
#     iter 10/100 — best fitness -461508.87136
#     iter 20/100 — best fitness -3320807.08542
#     iter 30/100 — best fitness -17697818.13434
#     iter 40/100 — best fitness -49390373.16521
#     iter 50/100 — best fitness -127062894.41777
#     iter 60/100 — best fitness -271317297.03342
#     iter 70/100 — best fitness -659412895.36115
#     iter 80/100 — best fitness -1521226767.34843
#     iter 90/100 — best fitness -2531036590.04813
#     iter 100/100 — best fitness -5103510771.39136
#   sample 2/50 (global 51)
#     iter 1/100 — best fitness 959.60083
#     iter 10/100 — best fitness -10888.43898
#     iter 20/100 — best fitness -18040.99280
#     iter 30/100 — best fitness -37110.66271
#     iter 40/100 — best fitness -56177.78563
#     iter 50/100 — best fitness -144389.56144
#     iter 60/100 — best fitness -200421.22775
#     iter 70/100 — best fitness -518694.00859
#     iter 80/100 — best fitness -699880.79374
#     iter 90/100 — best fitness -1102770.32997
#     iter 100/100 — best fitness -1461545.84713
#   sample 3/50 (global 52)
#     iter 1/100 — best fitness 957.77087
#     iter 10/100 — best fitness 947.64087
#     iter 20/100 — best fitness 944.86945
#     iter 30/100 — best fitness 941.81171
#     iter 40/100 — best fitness 935.04028
#     iter 50/100 — best fitness 933.65002
#     iter 60/100 — best fitness 931.17090
#     iter 70/100 — best fitness 929.53381
#     iter 80/100 — best fitness 926.00720
#     iter 90/100 — best fitness 921.20032
#     iter 100/100 — best fitness 919.49353
#   sample 4/50 (global 53)
#     iter 1/100 — best fitness -4008374.75000
#     iter 10/100 — best fitness -18881813.10428
#     iter 20/100 — best fitness -184933890.13844
#     iter 30/100 — best fitness -420938593.94342
#     iter 40/100 — best fitness -837470718.34963
#     iter 50/100 — best fitness -1416714988.21149
#     iter 60/100 — best fitness -1666379770.06171
#     iter 70/100 — best fitness -2345588554.26540
#     iter 80/100 — best fitness -3088382085.11639
#     iter 90/100 — best fitness -3733091556.64679
#     iter 100/100 — best fitness -4801023752.79486
#   sample 5/50 (global 54)
#     iter 1/100 — best fitness -14505.84082
#     iter 10/100 — best fitness -4284804.24629
#     iter 20/100 — best fitness -19207797.02965
#     iter 30/100 — best fitness -77968255.10803
#     iter 40/100 — best fitness -157562929.92157
#     iter 50/100 — best fitness -827244393.18430
#     iter 60/100 — best fitness -1830476094.82196
#     iter 70/100 — best fitness -2629680506.41983
#     iter 80/100 — best fitness -3910141757.34814
#     iter 90/100 — best fitness -14035816359.43384
#     iter 100/100 — best fitness -14453185962.83496
#   sample 6/50 (global 55)
#     iter 1/100 — best fitness -12544685753.76929
#     iter 10/100 — best fitness -36610683385.69904
#     iter 20/100 — best fitness -74577616654.74243
#     iter 30/100 — best fitness -92308329538.65942
#     iter 40/100 — best fitness -107304610203.92822
#     iter 50/100 — best fitness -112460249852.84259
#     iter 60/100 — best fitness -121009863803.97412
#     iter 70/100 — best fitness -124416264480.43121
#     iter 80/100 — best fitness -129721468869.85620
#     iter 90/100 — best fitness -132866400662.39502
#     iter 100/100 — best fitness -140144213621.91925
#   sample 7/50 (global 56)
#     iter 1/100 — best fitness -39801462784.00000
#     iter 10/100 — best fitness -53052128710.44055
#     iter 20/100 — best fitness -69129213260.33533
#     iter 30/100 — best fitness -89631089158.81714
#     iter 40/100 — best fitness -89741620014.95490
#     iter 50/100 — best fitness -99182023001.11322
#     iter 60/100 — best fitness -109780806491.22449
#     iter 70/100 — best fitness -112818116131.59082
#     iter 80/100 — best fitness -113168724957.63171
#     iter 90/100 — best fitness -121956519067.15851
#     iter 100/100 — best fitness -124127768456.45270
#   sample 8/50 (global 57)
#     iter 1/100 — best fitness -4596424704.00000
#     iter 10/100 — best fitness -34114936724.02576
#     iter 20/100 — best fitness -51795772503.00238
#     iter 30/100 — best fitness -75175489387.85150
#     iter 40/100 — best fitness -82732943424.51831
#     iter 50/100 — best fitness -87097138292.88757
#     iter 60/100 — best fitness -95782116781.76697
#     iter 70/100 — best fitness -97672890552.74768
#     iter 80/100 — best fitness -103166092762.58862
#     iter 90/100 — best fitness -108166779406.38574
#     iter 100/100 — best fitness -113110941775.68945
#   sample 9/50 (global 58)
#     iter 1/100 — best fitness -3184730576.19366
#     iter 10/100 — best fitness -15904688992.95325
#     iter 20/100 — best fitness -22816730908.90503
#     iter 30/100 — best fitness -27220345904.80292
#     iter 40/100 — best fitness -36322027597.69702
#     iter 50/100 — best fitness -51725982574.28528
#     iter 60/100 — best fitness -57134097959.91711
#     iter 70/100 — best fitness -63764218237.69971
#     iter 80/100 — best fitness -72166227250.20764
#     iter 90/100 — best fitness -74126614478.23108
#     iter 100/100 — best fitness -74998859313.29871
#   sample 10/50 (global 59)
#     iter 1/100 — best fitness -4526708.23567
#     iter 10/100 — best fitness -20384421.11256
#     iter 1/100 — best fitness -47861.68750
#     iter 10/100 — best fitness -426932.79970
#     iter 20/100 — best fitness -2452001.33959
#     iter 30/100 — best fitness -9263196.63972
#     iter 40/100 — best fitness -34283126.55572
#     iter 50/100 — best fitness -145316241.79824
#     iter 60/100 — best fitness -239731329.61479
#     iter 70/100 — best fitness -367633325.16523
#     iter 80/100 — best fitness -663356106.12461
#     iter 90/100 — best fitness -801974530.09581
#     iter 100/100 — best fitness -1083664441.46576
#   sample 17/50 (global 66)
#     iter 1/100 — best fitness -9687.82715
#     iter 10/100 — best fitness -1969334.93513
#     iter 20/100 — best fitness -15941247.21138
#     iter 30/100 — best fitness -41256736.39526
#     iter 40/100 — best fitness -239190145.70573
#     iter 50/100 — best fitness -595107915.14552
#     iter 60/100 — best fitness -958614513.20312
#     iter 70/100 — best fitness -1959401829.44730
#     iter 80/100 — best fitness -2866164906.05618
#     iter 90/100 — best fitness -3090224427.69006
#     iter 100/100 — best fitness -4156741067.02258
#   sample 18/50 (global 67)
#     iter 1/100 — best fitness -15669.76074
#     iter 10/100 — best fitness -109838.56282
#     iter 20/100 — best fitness -193276.70249
#     iter 30/100 — best fitness -1703536.25535
#     iter 40/100 — best fitness -5290472.73755
#     iter 50/100 — best fitness -15934089.14216
#     iter 60/100 — best fitness -25836366.37099
#     iter 70/100 — best fitness -34401937.87474
#     iter 80/100 — best fitness -49023823.49436
#     iter 90/100 — best fitness -72000235.70810
#     iter 100/100 — best fitness -92610464.95068
#   sample 19/50 (global 68)
#     iter 1/100 — best fitness -1205321956.99886
#     iter 10/100 — best fitness -3844758733.18839
#     iter 20/100 — best fitness -12923903640.16260
#     iter 30/100 — best fitness -24672075679.44379
#     iter 40/100 — best fitness -26274949474.94580
#     iter 50/100 — best fitness -35025991362.90125
#     iter 60/100 — best fitness -42312783159.77356
#     iter 70/100 — best fitness -52151111519.94592
#     iter 80/100 — best fitness -53403467096.04700
#     iter 90/100 — best fitness -55542186656.21191
#     iter 100/100 — best fitness -60693396486.54602
#   sample 20/50 (global 69)
#     iter 1/100 — best fitness -70979264512.00000
#     iter 10/100 — best fitness -84777468600.68774
#     iter 20/100 — best fitness -114657935065.66809
#     iter 30/100 — best fitness -123918475071.32776
#     iter 40/100 — best fitness -135044239907.79700
#     iter 50/100 — best fitness -141935357004.23584
#     iter 60/100 — best fitness -149458159355.68347
#     iter 70/100 — best fitness -150682896521.60474
#     iter 80/100 — best fitness -154173315908.05115
#     iter 90/100 — best fitness -162794455432.30457
#     iter 100/100 — best fitness -175114821334.54736
#   sample 21/50 (global 70)
#     iter 1/100 — best fitness -2102793.25851
#     iter 10/100 — best fitness -40291490.46109
#     iter 20/100 — best fitness -133902691.20226
#     iter 30/100 — best fitness -434983599.97144
#     iter 40/100 — best fitness -1059593817.69843
#     iter 50/100 — best fitness -4739304974.44952
#     iter 60/100 — best fitness -5760216905.62762
#     iter 70/100 — best fitness -7101083588.33466
#     iter 80/100 — best fitness -9016784022.09552
#     iter 90/100 — best fitness -11087068477.16504
#     iter 100/100 — best fitness -12766589113.84369
#   sample 22/50 (global 71)
#     iter 1/100 — best fitness -72605056.00000
#     iter 10/100 — best fitness -1713774255.63371
#     iter 20/100 — best fitness -4603920776.71021
#     iter 30/100 — best fitness -10170515929.15137
#     iter 40/100 — best fitness -21067241579.58582
#     iter 50/100 — best fitness -30441342733.68860
#     iter 60/100 — best fitness -33526863043.56903
#     iter 70/100 — best fitness -37887267010.79187
#     iter 80/100 — best fitness -42207092227.57208
#     iter 90/100 — best fitness -45746649641.04895
#     iter 100/100 — best fitness -49982036489.02734
#   sample 23/50 (global 72)
#     iter 1/100 — best fitness 965.14001
#     iter 10/100 — best fitness 955.79285
#     iter 20/100 — best fitness 932.08466
#     iter 30/100 — best fitness 929.64368
#     iter 40/100 — best fitness 928.98834
#     iter 50/100 — best fitness 924.69421
#     iter 60/100 — best fitness 919.33221
#     iter 70/100 — best fitness 917.54858
#     iter 80/100 — best fitness 914.48138
#     iter 90/100 — best fitness 914.09692
#     iter 100/100 — best fitness 910.06067
#   sample 24/50 (global 73)
#     iter 1/100 — best fitness 964.01422
#     iter 10/100 — best fitness 958.23279
#     iter 20/100 — best fitness 937.62036
#     iter 30/100 — best fitness 934.01569
#     iter 40/100 — best fitness -157.87017
#     iter 50/100 — best fitness -160.32976
#     iter 60/100 — best fitness -165.39275
#     iter 70/100 — best fitness -168.48162
#     iter 80/100 — best fitness -170.55718
#     iter 90/100 — best fitness -173.06731
#     iter 100/100 — best fitness -175.36382
#   sample 25/50 (global 74)
#     iter 1/100 — best fitness -5402480.09188
#     iter 10/100 — best fitness -35143193.26520
#     iter 20/100 — best fitness -301297875.20619
#     iter 30/100 — best fitness -1160625079.89255
#     iter 40/100 — best fitness -2597645675.58081
#     iter 50/100 — best fitness -6301282199.02155
#     iter 60/100 — best fitness -9599834831.48108
#     iter 70/100 — best fitness -10308493527.54907
#     iter 80/100 — best fitness -16277172715.08008
#     iter 90/100 — best fitness -20419079214.58521
#     iter 100/100 — best fitness -22579442412.93225
#   sample 26/50 (global 75)
#     iter 1/100 — best fitness -250510.57812
#     iter 10/100 — best fitness -30615073.84088
#     iter 20/100 — best fitness -170627901.00284
#     iter 30/100 — best fitness -1281718333.01894
#     iter 40/100 — best fitness -2191720028.20830
#     iter 50/100 — best fitness -6832029387.26361
#     iter 60/100 — best fitness -8349374698.58337
#     iter 70/100 — best fitness -14851453465.70276
#     iter 80/100 — best fitness -21393507878.48218
#     iter 90/100 — best fitness -23494151989.61401
#     iter 100/100 — best fitness -24572056688.81165
#   sample 27/50 (global 76)
#     iter 1/100 — best fitness -654465408.00000
#     iter 10/100 — best fitness -38286003023.65039
#     iter 20/100 — best fitness -54044994257.13855
#     iter 30/100 — best fitness -54849647422.94043
#     iter 40/100 — best fitness -64161270989.15430
#     iter 50/100 — best fitness -71682924159.00378
#     iter 60/100 — best fitness -74945091134.45337
#     iter 70/100 — best fitness -83272045975.21472
#     iter 80/100 — best fitness -85065630797.83020
#     iter 90/100 — best fitness -86305359723.45801
#     iter 100/100 — best fitness -89076775434.68030
#   sample 28/50 (global 77)
#     iter 1/100 — best fitness 955.79675
#     iter 10/100 — best fitness 923.23798
#     iter 20/100 — best fitness 918.72632
#     iter 30/100 — best fitness 916.18689
#     iter 40/100 — best fitness -202.22661
#     iter 50/100 — best fitness -202.44335
#     iter 60/100 — best fitness -205.43322
#     iter 70/100 — best fitness -207.92400
#     iter 80/100 — best fitness -209.57616
#     iter 90/100 — best fitness -2568.94023
#     iter 100/100 — best fitness -2571.26036
#   sample 29/50 (global 78)
#     iter 1/100 — best fitness 958.57123
#     iter 10/100 — best fitness 944.74091
#     iter 20/100 — best fitness 939.21997
#     iter 30/100 — best fitness 933.78607
#     iter 40/100 — best fitness 933.39124
#     iter 50/100 — best fitness 927.41089
#     iter 60/100 — best fitness 919.08563
#     iter 70/100 — best fitness 917.14813
#     iter 80/100 — best fitness 915.83301
#     iter 90/100 — best fitness 915.16565
#     iter 100/100 — best fitness 913.19812
#   sample 30/50 (global 79)
#     iter 1/100 — best fitness -249330.95312
#     iter 10/100 — best fitness -3312449.70375
#     iter 20/100 — best fitness -45682753.57564
#     iter 30/100 — best fitness -77435944.65126
#     iter 40/100 — best fitness -188346890.45278
#     iter 50/100 — best fitness -320303077.20423
#     iter 60/100 — best fitness -618613990.04619
#     iter 70/100 — best fitness -3823636055.11160
#     iter 80/100 — best fitness -5330799997.62836
#     iter 90/100 — best fitness -6743064701.42810
#     iter 100/100 — best fitness -9777977049.58911
#   sample 31/50 (global 80)
#     iter 1/100 — best fitness -193308.00000
#     iter 10/100 — best fitness -176709484.67021
#     iter 20/100 — best fitness -716060940.87132
#     iter 30/100 — best fitness -5513270068.56702
#     iter 40/100 — best fitness -6241893330.44672
#     iter 50/100 — best fitness -8162074841.95807
#     iter 60/100 — best fitness -13067681946.90906
#     iter 70/100 — best fitness -23142889895.88000
#     iter 80/100 — best fitness -28766747868.48938
#     iter 90/100 — best fitness -32309464369.93225
#     iter 100/100 — best fitness -33264087589.75452
#   sample 32/50 (global 81)
#     iter 1/100 — best fitness -971675.87500
#     iter 10/100 — best fitness -6006522.12375
#     iter 20/100 — best fitness -36456952.10391
#     iter 30/100 — best fitness -286990687.50577
#     iter 40/100 — best fitness -562883666.02987
#     iter 50/100 — best fitness -2193774593.55791
#     iter 60/100 — best fitness -4726653854.66901
#     iter 70/100 — best fitness -5082464377.24731
#     iter 80/100 — best fitness -6737221637.30298
#     iter 90/100 — best fitness -8417935529.43530
#     iter 100/100 — best fitness -10551918902.79602
#   sample 33/50 (global 82)
#     iter 1/100 — best fitness -89037668352.00000
#     iter 10/100 — best fitness -113215168881.82019
#     iter 20/100 — best fitness -138938149376.97461
#     iter 30/100 — best fitness -152306994361.19543
#     iter 40/100 — best fitness -161947268406.91162
#     iter 50/100 — best fitness -162344302094.65601
#     iter 60/100 — best fitness -165678862490.86011
#     iter 70/100 — best fitness -169706248204.20447
#     iter 80/100 — best fitness -172281130714.16040
#     iter 90/100 — best fitness -177519892618.54956
#     iter 100/100 — best fitness -181912421154.70459
#   sample 34/50 (global 83)
#     iter 1/100 — best fitness -671292.37500
#     iter 10/100 — best fitness -6969102.23950
#     iter 20/100 — best fitness -31613333.66507
#     iter 30/100 — best fitness -111930003.92006
#     iter 40/100 — best fitness -269332023.38177
#     iter 50/100 — best fitness -282798855.42479
#     iter 60/100 — best fitness -1006875562.67014
#     iter 70/100 — best fitness -1031312052.63258
#     iter 80/100 — best fitness -1381162103.00679
#     iter 90/100 — best fitness -1882776017.40550
#     iter 100/100 — best fitness -2795174564.31546
#   sample 35/50 (global 84)
#     iter 1/100 — best fitness -305998820.12453
#     iter 10/100 — best fitness -681136044.40804
#     iter 20/100 — best fitness -3357719340.50281
#     iter 30/100 — best fitness -8356643474.65973
#     iter 40/100 — best fitness -17371884734.11267
#     iter 50/100 — best fitness -25828303246.64685
#     iter 60/100 — best fitness -37161506560.82275
#     iter 70/100 — best fitness -41112870118.61511
#     iter 80/100 — best fitness -45409315963.36548
#     iter 90/100 — best fitness -52272342583.18835
#     iter 100/100 — best fitness -55398687264.68616
#   sample 36/50 (global 85)
#     iter 1/100 — best fitness -1380.69515
#     iter 10/100 — best fitness -21627.20296
#     iter 20/100 — best fitness -101507.53969
#     iter 30/100 — best fitness -347040.78627
#     iter 40/100 — best fitness -757094.76558
#     iter 50/100 — best fitness -1119450.61889
#     iter 60/100 — best fitness -2318486.50589
#     iter 70/100 — best fitness -4295536.83968
#     iter 80/100 — best fitness -5408409.76036
#     iter 90/100 — best fitness -8798695.29803
#     iter 100/100 — best fitness -14340279.72143
#   sample 37/50 (global 86)
#     iter 1/100 — best fitness -14470.37592
#     iter 10/100 — best fitness -109812.35249
#     iter 20/100 — best fitness -1435343.54152
#     iter 30/100 — best fitness -5320226.19848
#     iter 40/100 — best fitness -14073616.39919
#     iter 50/100 — best fitness -17665646.97582
#     iter 60/100 — best fitness -21612056.44748
#     iter 70/100 — best fitness -31067834.84817
#     iter 80/100 — best fitness -58617252.00645
#     iter 90/100 — best fitness -73961143.33949
#     iter 100/100 — best fitness -143565483.46992
#   sample 38/50 (global 87)
#     iter 1/100 — best fitness -107461.10156
#     iter 10/100 — best fitness -475844.41245
#     iter 20/100 — best fitness -2289956.36444
#     iter 30/100 — best fitness -5134418.50885
#     iter 40/100 — best fitness -8209161.48093
#     iter 50/100 — best fitness -20992362.31622
#     iter 60/100 — best fitness -49219592.26068
#     iter 70/100 — best fitness -80503942.85204
#     iter 80/100 — best fitness -120153660.79880
#     iter 90/100 — best fitness -168982380.02976
#     iter 100/100 — best fitness -223340192.72245
#   sample 39/50 (global 88)
#     iter 1/100 — best fitness -63788995.66690
#     iter 10/100 — best fitness -663571454.62719
#     iter 20/100 — best fitness -1521207413.52345
#     iter 30/100 — best fitness -6034972816.16064
#     iter 40/100 — best fitness -7902564587.80066
#     iter 50/100 — best fitness -12183997808.13837
#     iter 60/100 — best fitness -17610746798.89777
#     iter 70/100 — best fitness -21129931386.70532
#     iter 80/100 — best fitness -28396741326.14844
#     iter 90/100 — best fitness -32537957606.03003
#     iter 100/100 — best fitness -34772764618.52301
#   sample 40/50 (global 89)
#     iter 1/100 — best fitness -113455.96875
#     iter 10/100 — best fitness -1761940.62198
#     iter 20/100 — best fitness -7613563.05905
#     iter 30/100 — best fitness -43336466.99692
#     iter 40/100 — best fitness -86538940.03359
#     iter 50/100 — best fitness -204296790.73133
#     iter 60/100 — best fitness -290402664.00539
#     iter 70/100 — best fitness -323970302.37007
#     iter 80/100 — best fitness -369840472.71445
#     iter 90/100 — best fitness -548683239.26184
#     iter 100/100 — best fitness -806046744.38060
#   sample 41/50 (global 90)
#     iter 1/100 — best fitness -4488599.68733
#     iter 10/100 — best fitness -6129236.31759
#     iter 20/100 — best fitness -23027523.03312
#     iter 30/100 — best fitness -27075248.99291
# ...
#     iter 60/100 — best fitness -4959.04798
#     iter 70/100 — best fitness -6151.10277
#     iter 80/100 — best fitness -6151.69121
#     iter 90/100 — best fitness -8536.12027
#     iter 100/100 — best fitness -9730.60497
#   sample 25/50 (global 474)
#     iter 1/100 — best fitness -6150.11475
#     iter 10/100 — best fitness -72677216.99745
#     iter 20/100 — best fitness -244350798.25219
#     iter 30/100 — best fitness -738393395.67567
#     iter 40/100 — best fitness -1194647581.85930
#     iter 50/100 — best fitness -4020911933.63730
#     iter 60/100 — best fitness -10143459020.75275
#     iter 70/100 — best fitness -11903953729.01764
#     iter 80/100 — best fitness -16070383963.53979
#     iter 90/100 — best fitness -17288785157.10773
#     iter 100/100 — best fitness -20234660086.37073
#   sample 26/50 (global 475)
#     iter 1/100 — best fitness -16793364.00000
#     iter 10/100 — best fitness -6719954805.86890
#     iter 20/100 — best fitness -18604010533.24054
#     iter 30/100 — best fitness -26893836449.15393
#     iter 40/100 — best fitness -34861554094.61493
#     iter 50/100 — best fitness -36009279676.68079
#     iter 60/100 — best fitness -44003256742.09851
#     iter 70/100 — best fitness -50134881893.50745
#     iter 80/100 — best fitness -52817944445.75354
#     iter 90/100 — best fitness -57679652130.13782
#     iter 100/100 — best fitness -67330597820.07886
#   sample 27/50 (global 476)
#     iter 1/100 — best fitness -4801947.00000
#     iter 10/100 — best fitness -151286436.21337
#     iter 20/100 — best fitness -607881978.22757
#     iter 30/100 — best fitness -1915987015.40683
#     iter 40/100 — best fitness -27826744510.45264
#     iter 50/100 — best fitness -28299008800.17322
#     iter 60/100 — best fitness -31114782220.99731
#     iter 70/100 — best fitness -37954203080.97601
#     iter 80/100 — best fitness -48439454029.55634
#     iter 90/100 — best fitness -50180701205.54803
#     iter 100/100 — best fitness -51801675746.98651
#   sample 28/50 (global 477)
#     iter 1/100 — best fitness -109841.57649
#     iter 10/100 — best fitness -1680913.69235
#     iter 20/100 — best fitness -2935889.98098
#     iter 30/100 — best fitness -6589100.15114
#     iter 40/100 — best fitness -8910657.29142
#     iter 50/100 — best fitness -23140487.79051
#     iter 60/100 — best fitness -87386266.17415
#     iter 70/100 — best fitness -146136316.40421
#     iter 80/100 — best fitness -232780729.12263
#     iter 90/100 — best fitness -309703635.97642
#     iter 100/100 — best fitness -378458557.55220
#   sample 29/50 (global 478)
#     iter 1/100 — best fitness -188459586070.93518
#     iter 10/100 — best fitness -240244463854.66113
#     iter 20/100 — best fitness -276498297613.98901
#     iter 30/100 — best fitness -282784613532.08667
#     iter 40/100 — best fitness -284326323432.35742
#     iter 50/100 — best fitness -293468817632.92834
#     iter 60/100 — best fitness -311445998109.66309
#     iter 70/100 — best fitness -319265898621.39917
#     iter 80/100 — best fitness -323124731934.89136
#     iter 90/100 — best fitness -324929007447.96973
#     iter 100/100 — best fitness -329629095949.15588
#   sample 30/50 (global 479)
#     iter 1/100 — best fitness -9937321.00000
#     iter 10/100 — best fitness -209129899.03941
#     iter 20/100 — best fitness -1975406728.83955
#     iter 30/100 — best fitness -2722428319.75693
#     iter 40/100 — best fitness -4227392208.51276
#     iter 50/100 — best fitness -7534882555.74518
#     iter 60/100 — best fitness -17484650771.65442
#     iter 70/100 — best fitness -23164919772.83801
#     iter 80/100 — best fitness -27868603624.48926
#     iter 90/100 — best fitness -33960665623.36499
#     iter 100/100 — best fitness -37051102082.72534
#   sample 31/50 (global 480)
#     iter 1/100 — best fitness -169.65355
#     iter 10/100 — best fitness -171.60338
#     iter 20/100 — best fitness -64549.94234
#     iter 30/100 — best fitness -177796.72778
#     iter 40/100 — best fitness -450770.98114
#     iter 50/100 — best fitness -1759538.86317
#     iter 60/100 — best fitness -4585096.75947
#     iter 70/100 — best fitness -9022619.89942
#     iter 80/100 — best fitness -14700968.45807
#     iter 90/100 — best fitness -20352303.26498
#     iter 100/100 — best fitness -27842034.37608
#   sample 32/50 (global 481)
#     iter 1/100 — best fitness -22820.94818
#     iter 10/100 — best fitness -608126.40212
#     iter 20/100 — best fitness -2611715.09779
#     iter 30/100 — best fitness -7845830.88914
#     iter 40/100 — best fitness -21367060.52175
#     iter 50/100 — best fitness -39339231.07104
#     iter 60/100 — best fitness -65222202.26290
#     iter 70/100 — best fitness -255429918.13051
#     iter 80/100 — best fitness -308565187.93920
#     iter 90/100 — best fitness -496664465.02364
#     iter 100/100 — best fitness -762027174.04041
#   sample 33/50 (global 482)
#     iter 1/100 — best fitness 970.96716
#     iter 10/100 — best fitness 944.26648
#     iter 20/100 — best fitness 939.85114
#     iter 30/100 — best fitness -6137.29613
#     iter 40/100 — best fitness -32360.52801
#     iter 50/100 — best fitness -50242.37435
#     iter 60/100 — best fitness -100306.61971
#     iter 70/100 — best fitness -244548.21272
#     iter 80/100 — best fitness -245739.71259
#     iter 90/100 — best fitness -299379.96681
#     iter 100/100 — best fitness -395936.13262
#   sample 34/50 (global 483)
#     iter 1/100 — best fitness -73873213703.42725
#     iter 10/100 — best fitness -139939707683.67065
#     iter 20/100 — best fitness -143410757938.89990
#     iter 30/100 — best fitness -171015757469.29016
#     iter 40/100 — best fitness -184716814902.55664
#     iter 50/100 — best fitness -195178660298.27734
#     iter 60/100 — best fitness -203549727349.08936
#     iter 70/100 — best fitness -212403105647.26807
#     iter 80/100 — best fitness -219498309045.21497
#     iter 90/100 — best fitness -223560770897.70044
#     iter 80/100 — best fitness -109495810434.01733
#     iter 90/100 — best fitness -112087763711.28064
#     iter 100/100 — best fitness -115244969294.32397
#   sample 41/50 (global 490)
#     iter 1/100 — best fitness -708928448.00000
#     iter 10/100 — best fitness -87603243780.18488
#     iter 20/100 — best fitness -93496149969.01636
#     iter 30/100 — best fitness -106139639802.64288
#     iter 40/100 — best fitness -117235354367.44818
#     iter 50/100 — best fitness -123340052552.32233
#     iter 60/100 — best fitness -135027874890.34320
#     iter 70/100 — best fitness -143071650447.37720
#     iter 80/100 — best fitness -146609038297.06293
#     iter 90/100 — best fitness -151215771619.16791
#     iter 100/100 — best fitness -156224383297.76910
#   sample 42/50 (global 491)
#     iter 1/100 — best fitness -1063444.23301
#     iter 10/100 — best fitness -21796474.06526
#     iter 20/100 — best fitness -3043884521.57870
#     iter 30/100 — best fitness -11396740853.34045
#     iter 40/100 — best fitness -26798266344.88226
#     iter 50/100 — best fitness -41311658788.34631
#     iter 60/100 — best fitness -46369561120.83081
#     iter 70/100 — best fitness -57180332110.80347
#     iter 80/100 — best fitness -59022625849.02039
#     iter 90/100 — best fitness -64269174500.44409
#     iter 100/100 — best fitness -69175480766.91943
#   sample 43/50 (global 492)
#     iter 1/100 — best fitness -1323414180.26039
#     iter 10/100 — best fitness -28685134814.81299
#     iter 20/100 — best fitness -55160426038.53540
#     iter 30/100 — best fitness -67699965452.39374
#     iter 40/100 — best fitness -76427372901.47021
#     iter 50/100 — best fitness -83270672689.81970
#     iter 60/100 — best fitness -87400320897.34131
#     iter 70/100 — best fitness -94236754309.12561
#     iter 80/100 — best fitness -97184485326.69617
#     iter 90/100 — best fitness -99807528388.04297
#     iter 100/100 — best fitness -106767968072.78223
#   sample 44/50 (global 493)
#     iter 1/100 — best fitness -2141209718.74557
#     iter 10/100 — best fitness -31394530724.01306
#     iter 20/100 — best fitness -46769260350.75543
#     iter 30/100 — best fitness -57132653175.70367
#     iter 40/100 — best fitness -66655529918.31946
#     iter 50/100 — best fitness -70972536955.12439
#     iter 60/100 — best fitness -94503353987.06970
#     iter 70/100 — best fitness -97390440856.33813
#     iter 80/100 — best fitness -100797346984.24463
#     iter 90/100 — best fitness -110116175568.10022
#     iter 100/100 — best fitness -111184157287.11938
#   sample 45/50 (global 494)
#     iter 1/100 — best fitness -4067153813.65121
#     iter 10/100 — best fitness -16451755950.13599
#     iter 20/100 — best fitness -38979009576.78577
#     iter 30/100 — best fitness -56558908404.11212
#     iter 40/100 — best fitness -72457555706.82794
#     iter 50/100 — best fitness -86943644439.43616
#     iter 60/100 — best fitness -95472468286.08154
#     iter 70/100 — best fitness -106593912986.44299
#     iter 80/100 — best fitness -113986834431.78198
#     iter 90/100 — best fitness -118734463595.72839
#     iter 100/100 — best fitness -124604462528.05603
#   sample 46/50 (global 495)
#     iter 1/100 — best fitness -33543.35421
#     iter 10/100 — best fitness -525886.82570
#     iter 20/100 — best fitness -9753896.64918
#     iter 30/100 — best fitness -123143760.63345
#     iter 40/100 — best fitness -271533096.57827
#     iter 50/100 — best fitness -751558706.45386
#     iter 60/100 — best fitness -2463371629.39114
#     iter 70/100 — best fitness -3458264342.02206
#     iter 80/100 — best fitness -4303761886.05322
#     iter 90/100 — best fitness -8616844572.76013
#     iter 100/100 — best fitness -11148355165.34888
#   sample 47/50 (global 496)
#     iter 1/100 — best fitness -76239270166.71808
#     iter 10/100 — best fitness -96487254059.86511
#     iter 20/100 — best fitness -107855185414.98657
#     iter 30/100 — best fitness -128587149586.43567
#     iter 40/100 — best fitness -134367093043.23700
#     iter 50/100 — best fitness -145385760261.14777
#     iter 60/100 — best fitness -148388298928.73450
#     iter 70/100 — best fitness -162028445182.02655
#     iter 80/100 — best fitness -180488184864.02960
#     iter 90/100 — best fitness -185605372364.56848
#     iter 100/100 — best fitness -192160319262.81659
#   sample 48/50 (global 497)
#     iter 1/100 — best fitness -3747.55713
#     iter 10/100 — best fitness -25228.36403
#     iter 20/100 — best fitness -271944.20894
#     iter 30/100 — best fitness -533003.85741
#     iter 40/100 — best fitness -1821538.28345
#     iter 50/100 — best fitness -2264903.60103
#     iter 60/100 — best fitness -7289552.68286
#     iter 70/100 — best fitness -23460436.31973
#     iter 80/100 — best fitness -40538455.31466
#     iter 90/100 — best fitness -81973689.30864
#     iter 100/100 — best fitness -108711289.04193
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -143689516905.97717
#     iter 10/100 — best fitness -159221199869.73376
#     iter 20/100 — best fitness -181670740962.44031
#     iter 30/100 — best fitness -190722235553.49695
#     iter 40/100 — best fitness -192397879471.84863
#     iter 50/100 — best fitness -197761916032.27576
#     iter 60/100 — best fitness -204391936173.12329
#     iter 70/100 — best fitness -214942568646.68542
#     iter 80/100 — best fitness -219958456856.40625
#     iter 90/100 — best fitness -222346819739.83215
#     iter 100/100 — best fitness -224056071143.72864
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -47720040.00000
#     iter 10/100 — best fitness -2137965278.23830
#     iter 20/100 — best fitness -9701897063.26440
#     iter 30/100 — best fitness -19938446432.13916
#     iter 40/100 — best fitness -33058749585.07373
#     iter 50/100 — best fitness -38596488376.20142
#     iter 60/100 — best fitness -47500623597.81531
#     iter 70/100 — best fitness -55498365290.47827
#     iter 80/100 — best fitness -62726858980.06714
#     iter 90/100 — best fitness -66675328139.30286
#     iter 100/100 — best fitness -73104127769.37463
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 167
# Detailed results  CSV    : Generated Data/CSA_images\csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/CSA_images\csa_stats_per_digit.csv
# Total time               : 6399.36 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   40             10     50       80.0      20.0
# 1                   24             26     50       48.0      52.0
# 2                   48              2     50       96.0       4.0
# 3                   38             12     50       76.0      24.0
# 4                   23             27     50       46.0      54.0
# 5                   40             10     50       80.0      20.0
# 6                   40             10     50       80.0      20.0
# 7                   38             12     50       76.0      24.0
# 8                   26             24     50       52.0      48.0
# 9                   16             34     50       32.0      68.0

# %% [markdown]
# ## Perturbation on 500 Samples from test/unseen set

# %%
import os
import time
import joblib
import cv2
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F

# ──────────────────────────────────────────────────────────
# Numeric bounds & device
# ──────────────────────────────────────────────────────────
raw_upper_bound  = 50.0
raw_lower_bound  = -70.0
final_lower_bound = 0.0
final_upper_bound = 255.0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

raw_lower  = torch.tensor(raw_lower_bound,  dtype=torch.float32, device=device)
raw_upper  = torch.tensor(raw_upper_bound,  dtype=torch.float32, device=device)
final_lower = torch.tensor(final_lower_bound, dtype=torch.float32, device=device)
final_upper = torch.tensor(final_upper_bound, dtype=torch.float32, device=device)

img_shape = (28, 28)
dim = img_shape[0] * img_shape[1]

# ──────────────────────────────────────────────────────────
# CNN switch
# ──────────────────────────────────────────────────────────
# Flip this to True when you load a convolutional network that
# expects input shaped [N, C, H, W] rather than flattened.
CNN_MODE = False           # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# ──────────────────────────────────────────────────────────
# Helper functions
# ──────────────────────────────────────────────────────────
def clamp_tensor(x: torch.Tensor,
                 lower: torch.Tensor,
                 upper: torch.Tensor) -> torch.Tensor:
    """Clamp tensor values element‑wise between *lower* and *upper*."""
    return torch.max(torch.min(x, upper), lower)


def calculate_adversarial_loss(
    model: nn.Module,
    x_raw_single: torch.Tensor,
    y_single: torch.Tensor,
    eps: float = 1e-9
) -> torch.Tensor:
    """
    Black‑box cross‑entropy with ε‑floor (prevents CE == 0).

    Parameters
    ----------
    model  : nn.Module        – queried only in forward mode
    x_raw_single : [1, dim]   – raw pixels in [0,255]
    y_single     : [1]        – ground truth label
    eps          : float      – minimum CE to return
    """
    x_clip = clamp_tensor(x_raw_single, final_lower, final_upper)
    x_norm = x_clip / final_upper                       # scale to [0,1]

    if CNN_MODE:
        x_norm = x_norm.view(1, 1, *img_shape)          # keep CNN option

    # forward pass – still black‑box
    logits = model(x_norm)

    # CE for the single true class (no reduction over batch)
    log_probs = F.log_softmax(logits, dim=1)            # safe log
    ce = -log_probs[0, y_single]

    # floor to keep CE ≥ ε  (prevents fitness from flattening at 0)
    ce = torch.clamp(ce, min=eps)

    return ce



def save_uint8(img_arr: np.ndarray, path: str) -> None:
    """Round float32 array in [0,255] → uint8 and save with OpenCV."""
    img_u8 = np.clip(np.round(img_arr), final_lower_bound, final_upper_bound).astype(np.uint8)
    cv2.imwrite(path, img_u8)


# ──────────────────────────────────────────────────────────
# Load the trained model
# ──────────────────────────────────────────────────────────
MODEL_PATH = os.path.join("Models and Data splits", "MainModel_MLP1L.pt")

try:
    model = torch.jit.load(MODEL_PATH, map_location=device)
    model.to(device).eval()
    print(f"Model loaded successfully from {MODEL_PATH}")
except Exception as e:
    print(f"Error loading model from {MODEL_PATH}: {e}")
    model = None        # Guard in main()

# ──────────────────────────────────────────────────────────
# Cuckoo Search (single sample)
# ──────────────────────────────────────────────────────────
class CuckooSearchSingleSample:
    """
    Cuckoo‑Search meta‑heuristic to craft an adversarial perturbation
    for **one** image sample.
    """

    # --- constructor -------------------------------------------------
    def __init__(self,
                 n_nests: int,
                 n_iterations: int,
                 dim: int,
                 final_lower: torch.Tensor,
                 final_upper: torch.Tensor,
                 raw_lower: torch.Tensor,
                 raw_upper: torch.Tensor,
                 model: nn.Module,
                 X_sample: torch.Tensor,
                 y_sample: torch.Tensor,
                 p_a: float = 0.5,
                 lambda_param: float = 1e9,
                 step_size: float = 2.0,        
                 step_decay: float = 0.98):
        # Public params
        self.n_nests        = n_nests
        self.n_iterations   = n_iterations
        self.dim            = dim
        self.final_lower    = final_lower
        self.final_upper    = final_upper
        self.raw_lower      = raw_lower
        self.raw_upper      = raw_upper
        self.model          = model
        self.X              = X_sample.unsqueeze(0)   # [1, dim]
        self.y              = y_sample                # [1]
        self.p_a            = p_a
        self.lambda_param   = lambda_param
        self.step_size      = step_size               
        self.step_decay     = step_decay

        # --- population initialisation ------------------------------
        self.nests = torch.zeros((n_nests, dim), dtype=torch.float32, device=device)

        self.fitness = torch.empty(n_nests, dtype=torch.float32, device=device)
        for i in range(n_nests):
            self.fitness[i] = self._fitness(self.nests[i])

        best_idx = torch.argmin(self.fitness)
        self.best_nest    = self.nests[best_idx].clone()
        self.best_fitness = self.fitness[best_idx].item()

    # --- internals ---------------------------------------------------
    
    def _cauchy_flight(self) -> torch.Tensor:
        loc = torch.tensor(0.0, device=device)
        scale = torch.tensor(self.step_size, device=device)
        dist = torch.distributions.Cauchy(loc, scale)
        return dist.sample((self.dim,)) 

    def _new_solution(self, curr_perturb: torch.Tensor) -> torch.Tensor:
        flight = self._cauchy_flight()                              # [dim]
        cand   = clamp_tensor(curr_perturb + flight,
                              self.raw_lower, self.raw_upper)
        return cand

    def _fitness(self, perturb: torch.Tensor) -> float:
        """Fitness = ‖δ‖₂ − λ · CrossEntropy (untargeted)."""
        p_clip        = clamp_tensor(perturb, self.raw_lower, self.raw_upper)
        perturbed_raw = self.X + p_clip.unsqueeze(0)               # [1, dim]
        loss          = calculate_adversarial_loss(self.model,
                                                   perturbed_raw,
                                                   self.y).item()
        magnitude     = torch.norm(p_clip).item()
        return magnitude - self.lambda_param * loss

    # --- public API --------------------------------------------------
    def optimize(self) -> None:
        """Run Cuckoo‑Search for *n_iterations*."""
        for it in range(1, self.n_iterations + 1):
            # 1) generate new solutions
            for i in range(self.n_nests):
                cand      = self._new_solution(self.nests[i])
                cand_fit  = self._fitness(cand)

                if cand_fit < self.fitness[i]:
                    self.nests[i]  = cand
                    self.fitness[i]= cand_fit
                    if cand_fit < self.best_fitness:
                        self.best_fitness = cand_fit
                        self.best_nest    = cand.clone()

            # 2) abandon a fraction p_a of worst nests
            k = int(self.n_nests * self.p_a)
            if k > 0:
                worst_idx = torch.argsort(self.fitness)[-k:]
                for idx in worst_idx:
                    new_rand = torch.empty((self.dim,), dtype=torch.float32, device=device)\
                                  .uniform_(float(self.raw_lower),
                                            float(self.raw_upper))  
                    self.nests[idx]  = new_rand
                    self.fitness[idx]= self._fitness(new_rand)

            if it in {1, self.n_iterations} or it % 10 == 0:
                print(f"    iter {it}/{self.n_iterations} — best fitness {self.best_fitness:.5f}")

            # 3) step‑size schedule (optional)
            self.step_size *= self.step_decay                       

    def get_best_solution(self) -> torch.Tensor:
        """Return δ*  (shape [dim])."""
        return self.best_nest

# ──────────────────────────────────────────────────────────
# Main driver – sample‑by‑sample attack
# ──────────────────────────────────────────────────────────
def main() -> None:
    if model is None:
        print("Model not loaded; aborting.")
        return

    tic = time.time()
    print("Starting sample‑by‑sample adversarial generation …")

    # ---- load data --------------------------------------------------
    data_path = os.path.join("Models and Data splits", "MLP1L_500_samples_test.pkl")
    if not os.path.exists(data_path):
        print(f"Data file not found: {data_path}")
        return

    X_full_np, y_full_np = joblib.load(data_path)
    X_full = torch.tensor(X_full_np, dtype=torch.float32)
    y_full = torch.tensor(y_full_np, dtype=torch.long)
    print(f"Loaded X: {X_full.shape}, y: {y_full.shape}")

    # ---- output dirs -----------------------------------------------
    base_dir = "Generated Data/unseen_ZC-CSA_images"
    orig_dir = os.path.join(base_dir, "Original")
    adv_dir  = os.path.join(base_dir, "Adversarial")
    pert_dir = os.path.join(base_dir, "Perturbations")
    for d in (orig_dir, adv_dir, pert_dir):
        os.makedirs(d, exist_ok=True)

    # ---- hyper‑parameters ------------------------------------------
    n_nests       = 58
    n_iterations  = 100
    p_a           = 0.5
    lambda_param  = 1e10
    step_size     = 1.0      
    step_decay    = 0.98      # optional (1.0 disables decay)

    all_results = []
    processed   = 0
    adv_success = 0

    # ---- loop over digits ------------------------------------------
    for digit in range(10):     # process all digits now
        idxs = (y_full == digit).nonzero(as_tuple=True)[0]
        if idxs.numel() == 0:
            print(f"\nNo samples for digit {digit}; skipping.")
            continue

        print(f"\n── Processing digit {digit} ({idxs.numel()} samples) ──")
        X_class = X_full[idxs].to(device)
        y_class = y_full[idxs].to(device)

        for i in range(X_class.size(0)): 
            X_sample = X_class[i]                      # [dim]
            y_sample = y_class[i].unsqueeze(0)         # [1]
            gidx     = int(idxs[i])

            print(f"  sample {i+1}/{X_class.size(0)} (global {gidx})")

            # -- save original --------------------------------------
            save_uint8(X_sample.cpu().numpy().reshape(img_shape),
                       os.path.join(orig_dir, f"{gidx}_lbl{digit}.png"))

            # -- Cuckoo‑Search optimiser ---------------------------
            css = CuckooSearchSingleSample(
                n_nests      = n_nests,
                n_iterations = n_iterations,
                dim          = dim,
                final_lower  = final_lower,
                final_upper  = final_upper,
                raw_lower    = raw_lower,
                raw_upper    = raw_upper,
                model        = model,
                X_sample     = X_sample,
                y_sample     = y_sample,
                p_a          = p_a,
                lambda_param = lambda_param,
                step_size    = step_size,     
                step_decay   = step_decay,
            )
            css.optimize()
            delta_best = css.get_best_solution()

            # -- apply δ* ------------------------------------------
            adv_raw  = clamp_tensor(X_sample + delta_best, final_lower, final_upper)
            adv_norm = adv_raw.unsqueeze(0) / final_upper
            if CNN_MODE:
                adv_norm = adv_norm.view(1, 1, *img_shape)          

            with torch.no_grad():
                logits = model(adv_norm)
                pred   = torch.argmax(logits, dim=1)

            norm_l2  = torch.norm(delta_best).item()
            success  = (pred != y_sample).item()

            # -- save files ----------------------------------------
            delta_np = delta_best.cpu().numpy().reshape(img_shape)
            np.save(os.path.join(pert_dir, f"{gidx}_delta.npy"), delta_np)

            vis = ((delta_np - raw_lower_bound) / (raw_upper_bound - raw_lower_bound) * final_upper_bound)

            save_uint8(vis, os.path.join(pert_dir, f"{gidx}_delta_vis.png"))

            if success:
                adv_success += 1
                save_uint8(adv_raw.cpu().numpy().reshape(img_shape),
                           os.path.join(adv_dir,
                                        f"{gidx}_t{digit}_p{int(pred)}_m{norm_l2:.2f}.png"))

            # -- record row ----------------------------------------
            all_results.append(dict(
                digit=digit,
                index=gidx,
                true=digit,
                pred=int(pred),
                misclassified=success,
                perturb_norm_l2=norm_l2,
            ))

            processed += 1

    # ---- export CSV summary ----------------------------------------
    df = pd.DataFrame(all_results)
    csv_path = os.path.join(base_dir, "unseen_zc_csa_500x50_results.csv")
    df.to_csv(csv_path, index=False)

    # ---- per‑digit statistics --------------------------------------
    stats = (df.groupby(["digit", "misclassified"])
               .size()
               .unstack(fill_value=0)
               .rename(columns={False: "correct", True: "misclassified"}))
    
    # Ensure both columns always exist
    if "misclassified" not in stats.columns:
        stats["misclassified"] = 0
    if "correct" not in stats.columns:
        stats["correct"] = 0
    
    stats["total"]      = stats["correct"] + stats["misclassified"]
    stats["correct_%"]  = (stats["correct"]       / stats["total"] * 100).round(2)
    stats["miscls_%"]   = (stats["misclassified"] / stats["total"] * 100).round(2)


    stats_csv = os.path.join(base_dir, "unseen_zc_csa_stats_per_digit.csv")
    stats.to_csv(stats_csv)

    toc = time.time()

    # ---- pretty print ---------------------------------------------
    print("\n===== SUMMARY =====")
    print(f"Processed samples        : {processed}")
    print(f"Successful attacks       : {adv_success}")
    print(f"Detailed results  CSV    : {csv_path}")
    print(f"Per‑digit stats   CSV    : {stats_csv}")
    print(f"Total time               : {toc - tic:.2f} s\n")

    print(stats.to_string())


if __name__ == "__main__":
    main()
# Out:
# Model loaded successfully from Models and Data splits\MainModel_MLP1L.pt
# Starting sample‑by‑sample adversarial generation …
# Loaded X: torch.Size([500, 784]), y: torch.Size([500])
#
# ── Processing digit 0 (50 samples) ──
#   sample 1/50 (global 0)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -2524.63713
#     iter 20/100 — best fitness -714147.34456
#     iter 30/100 — best fitness -18725803.68482
#     iter 40/100 — best fitness -53534058.19714
#     iter 50/100 — best fitness -5233780186.34167
#     iter 60/100 — best fitness -14876130857.68250
#     iter 70/100 — best fitness -20916379727.26514
#     iter 80/100 — best fitness -21492446698.88794
#     iter 90/100 — best fitness -24078899657.18372
#     iter 100/100 — best fitness -30257638726.27161
#   sample 2/50 (global 1)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 3/50 (global 2)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -330340.26337
#     iter 20/100 — best fitness -3573351.10403
#     iter 30/100 — best fitness -7906508.96454
#     iter 40/100 — best fitness -55822272.93477
#     iter 50/100 — best fitness -217177100.90587
#     iter 60/100 — best fitness -2479289987.00905
#     iter 70/100 — best fitness -7899692119.04785
#     iter 80/100 — best fitness -24254258917.75854
#     iter 90/100 — best fitness -31476920882.34265
#     iter 100/100 — best fitness -58547338286.18250
#   sample 4/50 (global 3)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness

#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -11353130.80476
#     iter 20/100 — best fitness -208843791.05596
#     iter 30/100 — best fitness -3019514150.68896
#     iter 40/100 — best fitness -7283403932.95581
#     iter 50/100 — best fitness -9462903792.10669
#     iter 60/100 — best fitness -10367863233.15100
#     iter 70/100 — best fitness -20832711506.78723
#     iter 80/100 — best fitness -28646751687.45984
#     iter 90/100 — best fitness -36499680318.63696
#     iter 100/100 — best fitness -41581743988.13147
#   sample 39/50 (global 38)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 40/50 (global 39)
#     iter 1/100 — best fitness -64159.72908
#     iter 10/100 — best fitness -11992846840.13855
#     iter 20/100 — best fitness -43083285194.54138
#     iter 30/100 — best fitness -56760152664.34729
#     iter 40/100 — best fitness -86973789986.64246
#     iter 50/100 — best fitness -111924341949.20569
#     iter 60/100 — best fitness -124134539400.97180
#     iter 70/100 — best fitness -126608961855.16919
#     iter 80/100 — best fitness -153458546414.70312
#     iter 90/100 — best fitness -156312750590.89966
#     iter 100/100 — best fitness -163246458782.48962
#   sample 41/50 (global 40)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 42/50 (global 41)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 43/50 (global 42)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -140338168.20424
#     iter 20/100 — best fitness -9217329117.61328
#     iter 30/100 — best fitness -31800321407.98633
#     iter 40/100 — best fitness -39267300416.45850
#     iter 50/100 — best fitness -63329337880.63135
#     iter 60/100 — best fitness -71136950287.34058
#     iter 70/100 — best fitness -93019675045.16833
#     iter 80/100 — best fitness -101922673006.68176
#     iter 90/100 — best fitness -108023766298.61963
#     iter 100/100 — best fitness -119403809318.44043
#   sample 44/50 (global 43)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -1363.78780
#     iter 80/100 — best fitness -2552.90525
#     iter 90/100 — best fitness -15662.01944
#     iter 100/100 — best fitness -53794.22579
#   sample 45/50 (global 44)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 46/50 (global 45)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -3750.14413
#     iter 60/100 — best fitness -18045.03857
#     iter 70/100 — best fitness -300550.29347
#     iter 80/100 — best fitness -471006.35607
#     iter 90/100 — best fitness -1453180.94989
#     iter 100/100 — best fitness -7461021.55583
#   sample 47/50 (global 46)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 48/50 (global 47)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -49883602966.30566
#     iter 20/100 — best fitness -98406752419.33960
#     iter 30/100 — best fitness -112471417239.38208
#     iter 40/100 — best fitness -118689698036.39587
#     iter 50/100 — best fitness -142368563494.10352
#     iter 60/100 — best fitness -146901224929.98352
#     iter 70/100 — best fitness -183962611029.06128
#     iter 80/100 — best fitness -221094740686.80481
#     iter 90/100 — best fitness -225262583549.57739
#     iter 100/100 — best fitness -237126826097.33362
#   sample 49/50 (global 48)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#   sample 50/50 (global 49)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -10.00000
#     iter 20/100 — best fitness -10.00000
#     iter 30/100 — best fitness -10.00000
#     iter 40/100 — best fitness -10.00000
#     iter 50/100 — best fitness -10.00000
#     iter 60/100 — best fitness -10.00000
#     iter 70/100 — best fitness -10.00000
#     iter 80/100 — best fitness -10.00000
#     iter 90/100 — best fitness -10.00000
#     iter 100/100 — best fitness -10.00000
#
# ── Processing digit 1 (50 samples) ──
#   sample 1/50 (global 50)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -31729764.45440
#     iter 20/100 — best fitness -1615126824.48480
#     iter 30/100 — best fitness -15643588384.69275
#     iter 40/100 — best fitness -47482522796.77881
#     iter 50/100 — best fitness -58936647243.86133
#     iter 60/100 — best fitness -78108166496.19226
#     iter 70/100 — best fitness -87729786665.65576
#     iter 80/100 — best fitness -106676539221.77563
#     iter 90/100 — best fitness -113930081166.20630
#     iter 100/100 — best fitness -126089896001.61096
#   sample 2/50 (global 51)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -9648164630.11963
#     iter 20/100 — best fitness -42663110591.12878
#     iter 30/100 — best fitness -59496859395.05933
#     iter 40/100 — best fitness -88453606437.23083
#     iter 50/100 — best fitness -125104864902.66858
#     iter 60/100 — best fitness -139214400117.30383
#     iter 70/100 — best fitness -161445006195.15662
#     iter 80/100 — best fitness -166995486081.70508
#     iter 90/100 — best fitness -189300688557.10193
#     iter 100/100 — best fitness -197959440993.36316
#   sample 3/50 (global 52)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -
#     iter 80/100 — best fitness -233911284228.34424
#     iter 90/100 — best fitness -248257311605.17188
#     iter 100/100 — best fitness -249407576340.88818
#   sample 34/50 (global 483)
#     iter 1/100 — best fitness -5113700.79410
#     iter 10/100 — best fitness -75527972174.81848
#     iter 20/100 — best fitness -131826094548.17297
#     iter 30/100 — best fitness -167272280587.91650
#     iter 40/100 — best fitness -181376017371.33997
#     iter 50/100 — best fitness -226165331645.87842
#     iter 60/100 — best fitness -232751559054.16943
#     iter 70/100 — best fitness -237175730498.82214
#     iter 80/100 — best fitness -278095740103.60803
#     iter 90/100 — best fitness -279501971029.85645
#     iter 100/100 — best fitness -297083929800.40808
#   sample 35/50 (global 484)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -651589842.06672
#     iter 20/100 — best fitness -29878324372.04004
#     iter 30/100 — best fitness -59342197244.62146
#     iter 40/100 — best fitness -73238924789.75769
#     iter 50/100 — best fitness -142430886088.14185
#     iter 60/100 — best fitness -158933628847.53943
#     iter 70/100 — best fitness -185298289100.64551
#     iter 80/100 — best fitness -211098383697.28735
#     iter 90/100 — best fitness -231098250172.04187
#     iter 100/100 — best fitness -239427412770.86072
#   sample 36/50 (global 485)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -23555158513.93347
#     iter 20/100 — best fitness -79657281734.67273
#     iter 30/100 — best fitness -103911389199.37732
#     iter 40/100 — best fitness -128641957115.38696
#     iter 50/100 — best fitness -151729267898.61792
#     iter 60/100 — best fitness -159176758596.26453
#     iter 70/100 — best fitness -178174513638.36011
#     iter 80/100 — best fitness -202061861795.43945
#     iter 90/100 — best fitness -211012839116.66809
#     iter 100/100 — best fitness -219514502326.24194
#   sample 37/50 (global 486)
#     iter 1/100 — best fitness -12880.73030
#     iter 10/100 — best fitness -338268430.28366
#     iter 20/100 — best fitness -31447383287.16626
#     iter 30/100 — best fitness -59516676758.74634
#     iter 40/100 — best fitness -102296351272.42078
#     iter 50/100 — best fitness -132290419396.11633
#     iter 60/100 — best fitness -145415543375.64209
#     iter 70/100 — best fitness -186550444392.33423
#     iter 80/100 — best fitness -193201273710.68896
#     iter 90/100 — best fitness -222360590727.57019
#     iter 100/100 — best fitness -233125304004.39587
#   sample 38/50 (global 487)
#     iter 1/100 — best fitness -15475425.60380
#     iter 10/100 — best fitness -25246993450.34668
#     iter 20/100 — best fitness -97264298326.43250
#     iter 30/100 — best fitness -114185465644.44092
#     iter 40/100 — best fitness -135627726373.89722
#     iter 50/100 — best fitness -155754174047.00171
#     iter 60/100 — best fitness -171975764097.13477
#     iter 70/100 — best fitness -185062350116.03772
#     iter 80/100 — best fitness -209643172075.37122
#     iter 90/100 — best fitness -240145376971.15930
#     iter 100/100 — best fitness -258639258189.64783
#   sample 39/50 (global 488)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -184911.72643
#     iter 20/100 — best fitness -1765500.69451
#     iter 30/100 — best fitness -40051587.08089
#     iter 40/100 — best fitness -589465425.98174
#     iter 50/100 — best fitness -1555631836.96674
#     iter 60/100 — best fitness -12488609625.33105
#     iter 70/100 — best fitness -19845005344.30310
#     iter 80/100 — best fitness -20408228662.37134
#     iter 90/100 — best fitness -33494218652.69922

#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -11057858.80489
#     iter 20/100 — best fitness -1015965753.95676
#     iter 30/100 — best fitness -9309805096.18317
#     iter 40/100 — best fitness -37081803133.88330
#     iter 50/100 — best fitness -67768410506.37256
#     iter 60/100 — best fitness -88518074805.33008
#     iter 70/100 — best fitness -100552214436.87524
#     iter 80/100 — best fitness -109422844699.85962
#     iter 90/100 — best fitness -120629414351.06055
#     iter 100/100 — best fitness -139664086127.18457
#   sample 47/50 (global 496)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -776615276.43713
#     iter 20/100 — best fitness -33126205297.08740
#     iter 30/100 — best fitness -72720793557.92383
#     iter 40/100 — best fitness -84635104009.87476
#     iter 50/100 — best fitness -111366003810.53613
#     iter 60/100 — best fitness -118452004245.15186
#     iter 70/100 — best fitness -155007609166.79858
#     iter 80/100 — best fitness -166279944214.63000
#     iter 90/100 — best fitness -190269564424.30566
#     iter 100/100 — best fitness -195051497246.00671
#   sample 48/50 (global 497)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -4328160740.20035
#     iter 20/100 — best fitness -23658613085.27441
#     iter 30/100 — best fitness -43674615709.17517
#     iter 40/100 — best fitness -66597622736.65479
#     iter 50/100 — best fitness -99409846138.98523
#     iter 60/100 — best fitness -110845373941.75342
#     iter 70/100 — best fitness -126872319053.27686
#     iter 80/100 — best fitness -128269156283.77344
#     iter 90/100 — best fitness -143325060660.95081
#     iter 100/100 — best fitness -152014960105.79797
#   sample 49/50 (global 498)
#     iter 1/100 — best fitness -14041.43856
#     iter 10/100 — best fitness -152415943.58440
#     iter 20/100 — best fitness -2056312704.06519
#     iter 30/100 — best fitness -14999111969.65442
#     iter 40/100 — best fitness -34651790961.69482
#     iter 50/100 — best fitness -38060351715.38977
#     iter 60/100 — best fitness -55764211488.48608
#     iter 70/100 — best fitness -61495302984.15942
#     iter 80/100 — best fitness -68123735253.15051
#     iter 90/100 — best fitness -78656362325.40015
#     iter 100/100 — best fitness -83494843271.64734
#   sample 50/50 (global 499)
#     iter 1/100 — best fitness -10.00000
#     iter 10/100 — best fitness -26710339935.62585
#     iter 20/100 — best fitness -46964777836.60938
#     iter 30/100 — best fitness -94179829448.27832
#     iter 40/100 — best fitness -131856077987.59534
#     iter 50/100 — best fitness -177600439851.76208
#     iter 60/100 — best fitness -208330248642.26050
#     iter 70/100 — best fitness -217965716173.95239
#     iter 80/100 — best fitness -222581099323.15442
#     iter 90/100 — best fitness -233242510609.01001
#     iter 100/100 — best fitness -259348505787.57617
#
# ===== SUMMARY =====
# Processed samples        : 500
# Successful attacks       : 292
# Detailed results  CSV    : Generated Data/unseen_ZC-CSA_images\unseen_zc_csa_500x50_results.csv
# Per‑digit stats   CSV    : Generated Data/unseen_ZC-CSA_images\unseen_zc_csa_stats_per_digit.csv
# Total time               : 8264.80 s
#
# misclassified  correct  misclassified  total  correct_%  miscls_%
# digit
# 0                   34             16     50       68.0      32.0
# 1                    2             48     50        4.0      96.0
# 2                   39             11     50       78.0      22.0
# 3                   29             21     50       58.0      42.0
# 4                   11             39     50       22.0      78.0
# 5                   26             24     50       52.0      48.0
# 6                   23             27     50       46.0      54.0
# 7                   28             22     50       56.0      44.0
# 8                   14             36     50       28.0      72.0
# 9                    2             48     50        4.0      96.0
